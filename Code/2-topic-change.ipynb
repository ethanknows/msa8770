# %%
import nltk
import string
import csv
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from gensim import corpora, models
import pandas as pd

# %%
df  = pd.read_csv("Homework_1.csv",delimiter="^",header=None)
df2 = df[df[0]==8].sort_values(3)[[0,3,5]]
df3 = pd.DataFrame(df2.groupby(3,as_index=True).apply(lambda x: x.sum())[5]).reset_index()
df3
# Out:
#              3                                                  5
# 0   2015-10-15            essential for good living!! I love it!!
# 1   2015-10-23   This was my first attempt at grinding. I was ...
# 2   2015-10-25   It works well but the container is too small ...
# 3   2015-11-11   We own two of these. One for spices and one f...
# 4   2015-11-16   this is a Christmas present to someone...so d...
# 5   2015-11-19   Does the job perfectly. Nice shape for pourin...
# 6   2015-11-21   Since I bought it, I have used it almost ever...
# 7   2015-11-22                                           Perfect!
# 8   2015-11-23   I use it every morning. Works great! I put 8 ...
# 9   2015-12-01   Perfect Grinder! Now thats coffee This makes ...
# 10  2015-12-04   I just needed to grind my own coffee as I am ...
# 11  2015-12-08   Really great product. I use it for spices, co...
# 12  2015-12-16                               Powerful, work good.
# 13  2015-12-22   The key to a good coffee or spice grinder is ...
# 14  2015-12-23   Excellent tool. We had it for over a year wit...
# 15  2015-12-24                                        it grinds!!
# 16  2015-12-25                                     Wife loves it.
# 17  2015-12-26   Strong little grinder and works as you would ...
# 18  2015-12-27   I bought this for grinding dried peppers for ...
# 19  2015-12-30   I use this to pulverize my dehydrated hot pep...
# 20  2015-12-31   I have had this on my wish list for a while a...
# 21  2016-01-02   I buy and use whole spices from a health food...
# 22  2016-01-03   I love this product. It\s small so it\s easy ...
# 23  2016-01-04                                        GREAT VALUE
# 24  2016-01-06   Love this grinder. High quality and grinds pe...
# 25  2016-01-10   Works great Nice worked great. I bought this ...
# 26  2016-01-11   Small solution to grinding coffee with less c...
# 27  2016-01-12   so far so good after 3 months i\ve been using...
# 28  2016-01-13   Nice fine grounds does a great job. These uni...
# 29  2016-01-14   Works great. Used as a Spice Mill. Worked ext...
# 30  2016-01-15   ...strong motor...grinds coffee very quickly ...
# 31  2016-01-16   Works perfectly as advertised. Used for the f...
# 32  2016-01-17   Works well enough for its price. No issues. I...
# 33  2016-01-18   Basic coffee grinder, not very loud, grinds b...
# 34  2016-01-19   Grinds well, quiet but the lid leaves a littl...
# 35  2016-01-20   Grinding cup is not removable, and product is...
# 36  2016-01-21   Bought this one to replace an earlier model t...
# 37  2016-01-22   A year and half later, still works great!!!!!...

# %%
token_dict = {}
for date , comment in zip(df3[3],df3[5]):
    lowers = comment.lower()
    no_punctuation = lowers.translate(None, string.punctuation)
    token_dict[date] = no_punctuation
decode_token = [w.decode("utf-8") for w in token_dict.values()]

# %%
doc_tokens = [nltk.word_tokenize(doc) for doc in decode_token]
ps = PorterStemmer()
doc_stemmed = []
for one_doc in doc_tokens:
    doc_filtered = [w for w in one_doc if not w in stopwords.words("english")]
    doc_stem = [ps.stem(w).encode("utf-8") for w in doc_filtered]
    doc_stemmed.append(doc_stem)

# %%
dictionary = corpora.Dictionary(doc_stemmed)
corpus = [dictionary.doc2bow(text) for text in doc_stemmed]
ldamodel = models.ldamodel.LdaModel(corpus, num_topics=10, id2word = dictionary, passes = 20,chunksize=10000)

# %%
ldamodel.print_topics(num_topics=10, num_words=2)
# Out:
# [(0, u'0.017*"well" + 0.017*"work"'),
#  (1, u'0.040*"coffe" + 0.038*"grind"'),
#  (2, u'0.031*"time" + 0.027*"unit"'),
#  (3, u'0.018*"wife" + 0.018*"love"'),
#  (4, u'0.027*"use" + 0.014*"coffe"'),
#  (5, u'0.033*"coffe" + 0.026*"grind"'),
#  (6, u'0.030*"great" + 0.027*"small"'),
#  (7, u'0.027*"one" + 0.014*"use"'),
#  (8, u'0.049*"grind" + 0.041*"coffe"'),
#  (9, u'0.036*"grinder" + 0.028*"great"')]

# %%
raw_topics = [s for n,s in ldamodel.print_topics(num_topics=10, num_words=2)]
strip = '0123456789*."'
topics = [''.join([i for i in s.encode().replace(" +",",") if not i in strip]).replace(" +", ",") for s in raw_topics]

# %%
topics
# Out:
# ['well, work',
#  'coffe, grind',
#  'time, unit',
#  'wife, love',
#  'use, coffe',
#  'coffe, grind',
#  'great, small',
#  'one, use',
#  'grind, coffe',
#  'grinder, great']

# %%
prob_1 = []
prob_2 = []
for i in range(len(corpus)):
    df4 = pd.DataFrame(zip(topics,[p for t, p in ldamodel.get_document_topics(corpus[i],minimum_probability=1e-4)]),
                      columns = ["topics","prob"])
    df4.sort_values(by = "prob", ascending=0,inplace=True)
    df4 = df4.head(2)
    df4["top_two"] = df4.prob.map(str) + "*[" + df4.topics + "]"
    prob_1.append(df4.top_two.values[0])
    prob_2.append(df4.top_two.values[1])
result = pd.DataFrame(zip(df3[3],prob_1,prob_2)
                      ,columns=(["Time"," Probability*Topic 1", "Probability*Topic 2"]))
result
# Out:
#           Time              Probability*Topic 1  \
# 0   2015-10-15        0.819981784909*[one, use]
# 1   2015-10-23    0.935707885097*[coffe, grind]
# 2   2015-10-25        0.943740592339*[one, use]
# 3   2015-11-11    0.992372504731*[grind, coffe]
# 4   2015-11-16    0.629856899509*[grind, coffe]
# 5   2015-11-19    0.871423553588*[grind, coffe]
# 6   2015-11-21    0.699983556188*[great, small]
# 7   2015-11-22  0.978046444617*[grinder, great]
# 8   2015-11-23    0.924989061304*[coffe, grind]
# 9   2015-12-01    0.989772174597*[coffe, grind]
# 10  2015-12-04    0.924994886124*[great, small]
# 11  2015-12-08     0.96785356187*[coffe, grind]
# 12  2015-12-16      0.774967946424*[time, unit]
# 13  2015-12-22    0.909993165944*[coffe, grind]
# 14  2015-12-23    0.939995901644*[grind, coffe]
# 15  2015-12-24    0.992682569108*[grind, coffe]
# 16  2015-12-25      0.699978145139*[wife, love]
# 17  2015-12-26    0.549953743704*[grind, coffe]
# 18  2015-12-27    0.970965451356*[coffe, grind]
# 19  2015-12-30   0.96896406158*[grinder, great]
# 20  2015-12-31      0.887490504372*[well, work]
# 21  2016-01-02    0.979543553939*[coffe, grind]
# 22  2016-01-03    0.909996838807*[coffe, grind]
# 23  2016-01-04  0.949994844396*[grinder, great]
# 24  2016-01-06     0.52612387245*[grind, coffe]
# 25  2016-01-10    0.986362803766*[grind, coffe]
# 26  2016-01-11    0.994339263936*[grind, coffe]
# 27  2016-01-12      0.947055959955*[time, unit]
# 28  2016-01-13      0.887493766213*[use, coffe]
# 29  2016-01-14    0.703124279708*[coffe, grind]
# 30  2016-01-15    0.957137737881*[grind, coffe]
# 31  2016-01-16    0.983332058675*[coffe, grind]
# 32  2016-01-17      0.918174412298*[use, coffe]
# 33  2016-01-18      0.549978926341*[use, coffe]
# 34  2016-01-19    0.943746101571*[grind, coffe]
# 35  2016-01-20     0.91817403226*[great, small]
# 36  2016-01-21     0.85872068356*[coffe, grind]
# 37  2016-01-22    0.993181376253*[coffe, grind]
#
#                   Probability*Topic 2
# 0    0.0200046660537*[grinder, great]
# 1       0.00714583795912*[time, unit]
# 2     0.00625389464639*[grind, coffe]
# 3    0.000847575330308*[coffe, grind]
# 4       0.366040217268*[great, small]
# 5      0.0142877374403*[coffe, grind]
# 6    0.0333392556278*[grinder, great]
# 7     0.00243993332649*[grind, coffe]
# 8     0.00833704090848*[coffe, grind]
# 9     0.00113649122165*[great, small]
# 10    0.00833470068377*[coffe, grind]
# 11    0.00357263276662*[grind, coffe]
# 12     0.0250114915981*[grind, coffe]
# 13      0.010003224628*[grind, coffe]
# 14      0.00666817897746*[time, unit]
# 15   0.000813131293562*[coffe, grind]
# 16         0.0333381639205*[one, use]
# 17     0.0500192693904*[coffe, grind]
# 18    0.00322645574234*[grind, coffe]
# 19    0.00344874647191*[grind, coffe]
# 20     0.0125030058783*[grind, coffe]
# 21    0.00227328771612*[grind, coffe]
# 22     0.0100014577785*[grind, coffe]
# 23    0.00555752600029*[grind, coffe]
# 24        0.441435209829*[time, unit]
# 25    0.00151544018124*[coffe, grind]
# 26   0.000629023102183*[coffe, grind]
# 27    0.00588330293628*[grind, coffe]
# 28   0.0125016418457*[grinder, great]
# 29      0.204732788493*[grind, coffe]
# 30    0.00476364984685*[coffe, grind]
# 31    0.00185226271693*[grind, coffe]
# 32    0.00909341878859*[grind, coffe]
# 33     0.0500100081132*[grind, coffe]
# 34  0.00625104595673*[grinder, great]
# 35    0.00909320156656*[grind, coffe]
# 36      0.115468877251*[grind, coffe]
# 37    0.00075772934359*[grind, coffe]
