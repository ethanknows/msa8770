# %%
import string
import nltk
import string
import numpy as np
import csv
WordList = []
RatingList = []

with open('AmazonForClass1.csv', "r") as Amazoncsvfile:
    csvreader = csv.reader(Amazoncsvfile, delimiter = "^")
    for row in csvreader:
        text = row[-2]
        lowers = text.lower()
        no_punctuation = lowers.translate(None, string.punctuation)
        tokens = nltk.word_tokenize(no_punctuation)
        newtokens = [w for w in tokens if w.isalnum()]
        WordList.extend(newtokens)
fdist = nltk.FreqDist(WordList)
fdist.most_common(10)
# Out:
# [('the', 241),
#  ('and', 187),
#  ('i', 153),
#  ('to', 148),
#  ('it', 147),
#  ('a', 133),
#  ('for', 107),
#  ('is', 95),
#  ('of', 92),
#  ('this', 76)]

# %%
WordList
# Out:
# ['these',
#  'are',
#  'hands',
#  'down',
#  'the',
#  'best',
#  'quality',
#  'bands',
#  'for',
#  'the',
#  'money',
#  'i',
#  'am',
#  'a',
#  '38',
#  'year',
#  'old',
#  'male',
#  'and',
#  'wanted',
#  'a',
#  'resistance',
#  'band',
#  'set',
#  'that',
#  'i',
#  'could',
#  'travel',
#  'with',
#  'as',
#  'well',
#  'as',
#  'use',
#  'it',
#  'at',
#  'home',
#  'with',
#  'my',
#  'p90',
#  'workouts',
#  'i',
#  'specifically',
#  'wanted',
#  'bands',
#  'that',
#  'were',
#  'made',
#  'with',
#  'high',
#  'quality',
#  'material',
#  'and',
#  'would',
#  'not',
#  'break',
#  'after',
#  'a',
#  'few',
#  'months',
#  'after',
#  'months',
#  'of',
#  'research',
#  'i',
#  'pulled',
#  'the',
#  'trigger',
#  'and',
#  'bought',
#  'black',
#  'mountain',
#  'resistance',
#  'band',
#  'set',
#  'these',
#  'bands',
#  'met',
#  'all',
#  'of',
#  'my',
#  'expectations',
#  'and',
#  'more',
#  'they',
#  'are',
#  'high',
#  'quality',
#  'and',
# ...

# %%
text
# Out:
# ' Don\\t know why it\\s taken me so long to get one of these. Awesome kitchen tool!'

# %%
from nltk.corpus import stopwords
filtered = [w for w in WordList if not w in stopwords.words("english")]
#print WordList
#print filtered
fdist = nltk.FreqDist(filtered)
fdist.most_common(30)
#print stopwords.words("english")
# Out:
# [('great', 62),
#  ('good', 46),
#  ('use', 44),
#  ('product', 43),
#  ('quality', 34),
#  ('well', 33),
#  ('bands', 33),
#  ('easy', 27),
#  ('one', 25),
#  ('works', 24),
#  ('perfect', 22),
#  ('set', 21),
#  ('resistance', 18),
#  ('love', 17),
#  ('work', 17),
#  ('windows', 17),
#  ('used', 16),
#  ('like', 16),
#  ('time', 16),
#  ('would', 15),
#  ('tea', 15),
#  ('clean', 15),
#  ('get', 15),
#  ('ive', 15),
#  ('using', 14),
#  ('cold', 13),
#  ('house', 13),
#  ('price', 13),
#  ('home', 13),
#  ('brush', 13)]

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
example_words = ["using","use","used"]
[ps.stem(w) for w in example_words]
# Out:
# [u'use', 'use', u'use']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stemmed = [ps.stem(w) for w in filtered]
fdist = nltk.FreqDist(stemmed)
fdist.most_common(30)
# Out:
# [(u'use', 80),
#  (u'great', 62),
#  (u'work', 48),
#  (u'good', 46),
#  (u'product', 45),
#  (u'band', 43),
#  (u'qualiti', 34),
#  (u'well', 33),
#  (u'window', 29),
#  (u'one', 27),
#  (u'easi', 27),
#  (u'clean', 24),
#  (u'perfect', 22),
#  (u'get', 21),
#  (u'set', 21),
#  (u'love', 19),
#  (u'time', 19),
#  (u'resist', 18),
#  (u'bottl', 18),
#  (u'like', 17),
#  (u'buy', 16),
#  (u'would', 15),
#  (u'price', 15),
#  (u'tea', 15),
#  (u'ive', 15),
#  (u'purchas', 15),
#  (u'exercis', 15),
#  (u'brush', 15),
#  (u'room', 14),
#  (u'year', 14)]

# %%
for subdir, dirs, files in os.walk(path):
    for file in files:
        print file
# Out:
# 4. Introduction to NLP I.ipynb
# 5. Introduction to NLP II.ipynb
# 6. Introduction to NLP III.ipynb
# AmazonForClass1.csv
# AmazonForClass2.csv
# AmazonForClass3.csv
# SampleText.txt
# SampleTwitter.txt
# TFIDFcode.txt
# Untitled.ipynb
# 6. Introduction to NLP III-checkpoint.ipynb
# Untitled-checkpoint.ipynb

# %%
token_dict.values()
# Out:
# [' these are hands down the best quality bands for the money i am a 38 year old male and wanted a resistance band set that i could travel with as well as use it at home with my p90 workouts i specifically wanted bands that were made with high quality material and would not break after a few months after months of research i pulled the trigger and bought black mountain resistance band set these bands met all of my expectations and more they are high quality and multiple bands can be combined for added resistance the travel bag makes it easy to travel with since i am always on the go my wife always really liked them and we ordered a second set to replace her flimsy less quality bands thanks black mountain for producing a great product at a fraction of what other competitors are selling them for i just got this set yesterday as well as a set from another company so i could compare the quality the other set seems to be made pretty well but these from black mountain are higher quality the
# ...

# %%
tfidf
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=<function tokenize at 0x110b56050>, use_idf=True,
#         vocabulary=None)

# %%
import nltk
import string
import os
import csv
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.porter import PorterStemmer

path = '/Users/ethan/Desktop/MSA_8770/Code'
token_dict = {}
stemmer = PorterStemmer()

def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    tokens = nltk.word_tokenize(text)
    newtokens = [w for w in tokens if w.isalnum()]
    stems = stem_tokens(tokens, stemmer)
    return stems

for subdir, dirs, files in os.walk(path):
    for file in files:
      if file.startswith("A"):
        file_path = subdir + os.path.sep + file
        print file_path
        Amazoncsvfile = open(file_path, 'r')
        csvreader = csv.reader(Amazoncsvfile, delimiter = "^")
        text = "" 
        #count = 0
        for row in csvreader:
            #count +=1
            #if count ==5:
                text = text + row[-2]
        lowers = text.lower()
        no_punctuation = lowers.translate(None, string.punctuation)
        token_dict[file] = no_punctuation
        
#this can take some time
tfidf = TfidfVectorizer(tokenizer=tokenize, stop_words='english')
tfs = tfidf.fit_transform(token_dict.values())
#print tfidf.get_feature_names()
print tfs
# Out:
# /Users/ethan/Desktop/MSA_8770/Code/AmazonForClass1.csv
# /Users/ethan/Desktop/MSA_8770/Code/AmazonForClass2.csv
# /Users/ethan/Desktop/MSA_8770/Code/AmazonForClass3.csv
#   (0, 751)	0.00436790581378
#   (0, 175)	0.0305753406965
#   (0, 1262)	0.148508797668
#   (0, 147)	0.318006818783
#   (0, 1023)	0.0337468440634
#   (0, 32)	0.00739550741355
#   (0, 1874)	0.0611506813929
#   (0, 1096)	0.0218395290689
#   (0, 974)	0.00739550741355
#   (0, 1791)	0.0174716232551
#   (0, 1334)	0.133119133444
#   (0, 1421)	0.0917260220894
#   (0, 1703)	0.0739550741355
#   (0, 1756)	0.349432465102
#   (0, 788)	0.0731181621373
#   (0, 1128)	0.00739550741355
#   (0, 1857)	0.0739550741355
#   (0, 1529)	0.0147910148271
#   (0, 779)	0.0174716232551
#   (0, 988)	0.0262074348827
#   (0, 213)	0.0131037174413
#   (0, 1025)	0.039311152324
#   (0, 1331)	0.0112489480211
#   (0, 1249)	0.0112489480211
#   (0, 1708)	0.00739550741355
#   :	:
#   (2, 1468)	0.007582175349
#   (2, 717)	0.015164350698
# ...

# %%
len(tfidf.get_feature_names())
# Out:
# 1888

# %%
token_dict
# Out:
# {'AmazonForClass1.csv': ' these are hands down the best quality bands for the money i am a 38 year old male and wanted a resistance band set that i could travel with as well as use it at home with my p90 workouts i specifically wanted bands that were made with high quality material and would not break after a few months after months of research i pulled the trigger and bought black mountain resistance band set these bands met all of my expectations and more they are high quality and multiple bands can be combined for added resistance the travel bag makes it easy to travel with since i am always on the go my wife always really liked them and we ordered a second set to replace her flimsy less quality bands thanks black mountain for producing a great product at a fraction of what other competitors are selling them for i just got this set yesterday as well as a set from another company so i could compare the quality the other set seems to be made pretty well but these from black mountain
# ...

# %%
tfs.shape
# Out:
# (3, 1888)

# %%
str = 'this sentence has unseen and like good text such as computer but also king lord juliet'
response = tfidf.transform([str])
print response
# Out:
#   (0, 1658)	0.5
#   (0, 937)	0.5
#   (0, 746)	0.5
#   (0, 705)	0.5

# %%
feature_names = tfidf.get_feature_names()
for col in tfs.nonzero()[1]:
    print feature_names[col], ' - ', response[0, col]
# Out:
# hand  -  0.0
# best  -  0.0
# qualiti  -  0.0
# band  -  0.0
# money  -  0.0
# 38  -  0.0
# year  -  0.0
# old  -  0.0
# male  -  0.0
# want  -  0.0
# resist  -  0.0
# set  -  0.0
# travel  -  0.0
# use  -  0.0
# home  -  0.0
# p90  -  0.0
# workout  -  0.0
# specif  -  0.0
# high  -  0.0
# materi  -  0.0
# break  -  0.0
# month  -  0.0
# research  -  0.0
# pull  -  0.0
# trigger  -  0.0
# bought  -  0.0
# black  -  0.0
# mountain  -  0.0
# met  -  0.0
# expect  -  0.0
# multipl  -  0.0
# combin  -  0.0
# ad  -  0.0
# bag  -  0.0
# make  -  0.0
# easi  -  0.0
# sinc  -  0.0
# alway  -  0.0
# wife  -  0.0
# realli  -  0.0
# like  -  0.5
# order  -  0.0
# second  -  0.0
# replac  -  0.0
# flimsi  -  0.0
# thank  -  0.0
# produc  -  0.0
# great  -  0.0
# product  -  0.0
# fraction  -  0.0
# competitor  -  0.0
# sell  -  0.0
# just  -  0.0
# got  -  0.0
# thi  -  0.5
# yesterday  -  0.0
# anoth  -  0.0
# compani  -  0.0
# compar  -  0.0
# pretti  -  0.0
# higher  -  0.0
# nylon  -  0.0
# ...

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_similarities = linear_kernel(tfs[1:2],tfs).flatten()
print cosine_similarities
# Out:
# [ 0.5145937   1.          0.52772181]

# %%
tfs[0:2]
# Out:
# <2x1888 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1948 stored elements in Compressed Sparse Row format>

# %%
print tfidf
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=<function tokenize at 0x1140b2aa0>, use_idf=True,
#         vocabulary=None)
