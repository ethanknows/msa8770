# %%
import nltk
import string
import csv
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from gensim import corpora, models
import pandas as pd
import numpy as np

# %%
token_dict = {}
for file in range(1,20):
    text = ""
    Homeworkcsvfile = open("Homework_1.csv","r",)
    csvreader = csv.reader(Homeworkcsvfile, delimiter = "^")
    for row in csvreader:
        if row[0] == str(file):
            text = text + row[-2]
    lowers = text.lower()
    no_punctuation = lowers.translate(None, string.punctuation)
    token_dict[file] = no_punctuation
decode_token = [w.decode("utf-8") for w in token_dict.values()]

# %%
token_dict.values()
# Out:
# [' these are hands down the best quality bands for the money i am a 38 year old male and wanted a resistance band set that i could travel with as well as use it at home with my p90 workouts i specifically wanted bands that were made with high quality material and would not break after a few months after months of research i pulled the trigger and bought black mountain resistance band set these bands met all of my expectations and more they are high quality and multiple bands can be combined for added resistance the travel bag makes it easy to travel with since i am always on the go my wife always really liked them and we ordered a second set to replace her flimsy less quality bands thanks black mountain for producing a great product at a fraction of what other competitors are selling them for i just got this set yesterday as well as a set from another company so i could compare the quality the other set seems to be made pretty well but these from black mountain are higher quality the nylon webbing and hardware are heavier and have an overall better quality look ive been using resistance bands for years not as my sole resistance routine but to suppliment my exercise machines and free weights everyone that exercises should give bands a try if they havent as they are very effective as these eventually wear out as they all do in time ill replace them with black mountain products again my only complaint is there is a slip of paper that came with the bands offering me a free orange band but the phone number given doesnt seem to connect to anything my husband uses these and finds them to be good for his arthritis stretching exercises i got these for christmas and have been using them multiple days a week since the resistance is great i would agree that the low resistance is pretty worthless but maybe some use it i was a little skeptical about the customer service given the review but i called to inquire about these before purchase and they answered right away which gave me a little more confidence so far so good i will let you know if there are any issues with the bands themselves after continue usage between 34xwk havent had it long enough to use all of the components but so far im impressed with the quality of the material i also really like the fact that you can remove and mixmatch the bands using the hooks on each end all in all so far so good and they do what theyre meant to do will update once i can try the other exercise positions using the door anchor im not a weight guy and ive tried resistance bands in the past and was never that impressed this product is great it doesnt have that flimsy cheap feel it feels solid and offers good resistance and is easy to use ive used it now for a while and i will keep on using it instead of throwing it in some drawer to gather dust i would highly recommend this product for both beginners and veterans and it is compact enough to take with me on trips i love this product upon first receiving it i was skeptical that these would provide a good workout but i can assure you after doing a little 10 minute workout found on youtube these little bands deliver i was so sore after just a short workout i highly recommend this product to anyone considering a home exercise product to keep themselves fit excellent packaging the whole set fits neatly into the carrying bag excellent for travel the bands appear to be of superior quality when compared to spri connecters work well as does the door mount stacking the bands is easy and quality control has ensured that the bands are of consistent length awesome purchase received these as a gift construction seems pretty legit i like the carabiners vice plastic clips of competitors the handles and other attachment points feel quality perfect to stay on track while traveling and cant take the weights with me would recommend this product and company to friends and family alot of bang \xc3\xb0\xc2\xa5 for the buck effective work out without the hassles of changing wei ...
get a good one now i need to reorder one of the 3 blades is dull which make me wonder if this is a factory replacement head  just what i expected shipping was an issue but they resent with no problem improved shaving experience with new blades it fits like the original blades i use it less since i grew back my beard but its still great for trimming  i really didnt notice a difference from my existing to the new ones easy shopping and good price will by again for next replacemenet only received foil replacements was expecting the complete head best way to godont throw money away for a new electric razor i have used these for years and they give a great shave good replacement for you norelco to keep it new cuts close like the original blades great product i would buy it again husband loves this great value makes my old razor like new fits the razor as listed very pleased work great just as expected easy to repalce as advertised perfect great works none ok']

# %%
doc_tokens = [nltk.word_tokenize(doc) for doc in decode_token]
ps = PorterStemmer()
doc_stemmed = []
for one_doc in doc_tokens:
    doc_filtered = [w for w in one_doc if not w in stopwords.words("english")]
    doc_stem = [ps.stem(w).encode("utf-8") for w in doc_filtered]
    doc_stemmed.append(doc_stem)

# %%
doc_stemmed
# Out:
# [['hand',
#   'best',
#   'qualiti',
#   'band',
#   'money',
#   '38',
#   'year',
#   'old',
#   'male',
#   'want',
#   'resist',
#   'band',
#   'set',
#   'could',
#   'travel',
#   'well',
#   'use',
#   'home',
#   'p90',
#   'workout',
#   'specif',
#   'want',
#   'band',
#   'made',
#   'high',
#   'qualiti',
#   'materi',
#   'would',
#   'break',
#   'month',
#   'month',
#   'research',
#   'pull',
#   'trigger',
#   'bought',
#   'black',
#   'mountain',
#   'resist',
#   'band',
#   'set',
#   'band',
#   'met',
#   'expect',
#   'high',
#   'qualiti',
#   'multipl',
#   'band',
#   'combin',
#   'ad',
#   'resist',
#   'travel',
#   'bag',
#   'make',
#   'easi',
#   'travel',
#   'sinc',
#   'alway',
#   'go',
#   'wife',
#   'alway',
#   'realli',
#   'like',
#   'order',
#   'second',
#   'set',
#   'replac',
#   'flimsi',
#   'less',
#   'qualiti',
#   'band',
#   'thank',
#   'black',
#   'mountain',
#   'produc',
#   'great',
#   'product',
#   'fraction',
#   'competitor',
#   'sell',
#   'got',
#   'set',
#   'yesterday',
#   'well',
#   'set',
#   'anoth',
#   'compani',
#   'could',
#   'compar',
#   'qualiti',
#   'set',
#   'seem',
#   'made',
#   'pretti',
#   'well',
#   'black',
#   'mountain',
#   'higher',
#   'qualiti',
#   'nylon',
#   'web',
#   'hardwar',
#   'heavier',
#   'overal',
#   'better',
#   'qualiti',
#   'look',
#   'ive',
#   'use',
#   'resist',
#   'band',
#   'year',
#   'sole',
#   'resist',
#   'routin',
#   'suppliment',
#   'exercis',
#   'machin',
#   'free',
#   'weight',
#   'everyon',
#   'exercis',
#   'give',
#   'band',
#   'tri',
#   'havent',
#   'effect',
#   'eventu',
#   'wear',
#   'time',
#   'ill',
#   'replac',
#   'black',
#   'mountain',
#   'product',
#   'complaint',
#   'slip',
#   'paper',
#   'came',
#   'band',
#   'offer',
#   'free',
#   'orang',
#   'band',
#   'phone',
#   'number',
#   'given',
#   'doesnt',
#   'seem',
#   'connect',
#   'anyth',
#   'husband',
#   'use',
#   'find',
#   'good',
#   'arthriti',
#   'stretch',
#   'exercis',
#   'got',
#   'christma',
#   'use',
#   'multipl',
#   'day',
#   'week',
#   'sinc',
#   'resist',
#   'great',
#   'would',
#   'agre',
#   'low',
#   'resist',
#   'pretti',
#   'worthless',
#   'mayb',
#   'use',
#   'littl',
#   'skeptic',
#   'custom',
#   'servic',
#   'given',
#   'review',
#   'call',
#   'inquir',
#   'purchas',
#   'answer',
#   'right',
#   'away',
#   'gave',
#   'littl',
#   'confid',
#   'far',
#   'good',
#   'let',
#   'know',
#   'issu',
#   'band',
#   'continu',
#   'usag',
#   '34xwk',
#   'havent',
#   'long',
#   'enough',
#   'use',
#   'compon',
#   'far',
#   'im',
#   'impress',
#   'qualiti',
#   'materi',
#   'also',
#   'realli',
#   'like',
#   'fact',
#   'remov',
#   'mixmatch',
#   'band',
#   'use',
#   'hook',
#   'end',
#   'far',
#   'good',
#   'theyr',
#   'meant',
#   'updat',
#   'tri',
#   'exercis',
#   'posit',
#   'use',
#   'door',
#   'anchor',
#   'im',
#   'weight',
#   'guy',
#   'ive',
#   'tri',
#   'resist',
#   'band',
#   'past',
#   'never',
#   'impress',
#   'product',
#   'great',
#   'doesnt',
#   'flimsi',
#   'cheap',
#   'feel',
#   'feel',
#   'solid',
#   'offer',
#   'good',
#   'resist',
#   'easi',
#   'use',
#   'ive',
#   'use',
#   'keep',
#   'use',
#   'instead',
#   'throw',
#   'drawer',
#   'gather',
#   'dust',
#   'would',
#   'highli',
#   'recommend',
#   'product',
#   'beginn',
#   'veteran',
#   'compact',
#   'enough',
#   'take',
#   'trip',
#   'love',
#   'product',
#   'upon',
#   'first',
#   'receiv',
#   'skeptic',
#   'would',
#   'provid',
#   'good',
#   'workout',
#   'assur',
#   'littl',
#   '10',
#   'minut',
#   'workout',
#   'found',
#   'youtub',
#   'littl',
#   'band',
#   'deliv',
#   'sore',
#   'short',
#   'workout',
#   'highli',
#   'recommend',
#   'product',
#   'anyon',
#   'consid',
#   'home',
#   'exercis',
#   'product',
#   'keep',
#   'fit',
#   'excel',
#   'packag',
#   'whole',
#   'set',
#   'fit',
#   'neatli',
#   'carri',
#   'bag',
#   'excel',
#   'travel',
#   'band',
#   'appear',
#   'superior',
#   'qualiti',
#   'compar',
#   'spri',
#   'connect',
#   'work',
#   'well',
#   'door',
#   'mount',
#   'stack',
#   'band',
#   'easi',
#   'qualiti',
#   'control',
#   'ensur',
#   'band',
#   'consist',
#   'length',
#   'awesom',
#   'purchas',
#   'receiv',
#   'gift',
#   'construct',
#   'seem',
#   'pretti',
#   'legit',
#   'like',
#   'carabin',
#   'vice',
#   'plastic',
#   'clip',
#   'competitor',
#   'handl',
#   'attach',
#   'point',
#   'feel',
#   'qualiti',
#   'perfect',
#   'stay',
#   'track',
#   'travel',
#   'cant',
#   'take',
#   'weight',
#   'would',
#   'recommend',
#   'product',
#   'compani',
#   'friend',
#   'famili',
#   'alot',
#   'bang',
#   '\xc3\xb0\xc2\xa5',
#   'buck',
#   'effect',
#   'work',
#   'without',
#   'hassl',
#   'chang',
#   'weight',
#   'buy',
#   'expens',
#   'equip',
#   'best',
#   'take',
#   'travel',
#   'come',
#   'carri',
#   'case',
#   'instruct',
#   'manual',
#   'clearli',
#   'show',
#   'differ',
#   'exercis',
#   'set',
#   'need',
#   'good',
#   'light',
#   'workout',
#   'portabl',
#   'give',
#   'varieti',
#   'exercis',
#   'take',
#   'much',
#   'less',
#   'space',
#   'set',
#   'dumbel',
#   'band',
#   'sturdi',
#   'connect',
#   'end',
#   'solid',
#   'seem',
#   'well',
#   'made',
#   'overal',
#   'good',
#   'valu',
#   'long',
#   'arent',
#   'look',
#   'real',
#   'heavi',
#   'lift',
#   'purchas',
#   'band',
#   'help',
#   'restrengthen',
#   'shoulder',
#   'surgeri',
#   'happi',
#   'qualiti',
#   'excel',
#   'fast',
#   'easi',
#   'chang',
#   'handl',
#   'one',
#   'band',
#   'anoth',
#   'carrybag',
#   'made',
#   'easi',
#   'take',
#   'wherev',
#   'might',
#   'travel',
#   'highli',
#   'recommend',
#   'tore',
#   'littl',
#   'year',
#   'im',
#   'strong',
#   'poor',
#   'qualiti',
#   'also',
#   'one',
#   'handl',
#   'got',
#   'bent',
#   'still',
#   'work',
#   'tear',
#   'pain',
#   'suggest',
#   'must',
#   'buy',
#   'brand',
#   'replac',
#   'everi',
#   'year',
#   'perfect',
#   'home',
#   'gym',
#   'easier',
#   'store',
#   'move',
#   'dumbbel',
#   'significantli',
#   'cheaper',
#   'handl',
#   'door',
#   'frame',
#   'loop',
#   'advantag',
#   'tradit',
#   'band',
#   'make',
#   'feel',
#   'like',
#   'gym',
#   'machin',
#   'exercis',
#   'band',
#   'great',
#   'product',
#   'dont',
#   'time',
#   'go',
#   'gym',
#   'product',
#   'good',
#   'take',
#   'anywher',
#   'start',
#   'use',
#   'p90x',
#   'work',
#   'well',
#   'im',
#   'happi',
#   'product',
#   'would',
#   'recommend',
#   'anyon',
#   'bought',
#   'use',
#   'physic',
#   'therapi',
#   'pretti',
#   'happi',
#   'conveni',
#   'factor',
#   'cumbersom',
#   'though',
#   'switch',
#   'differ',
#   'band',
#   'hour',
#   'hour',
#   'half',
#   'work',
#   'good',
#   'set',
#   'resist',
#   'train',
#   'equip',
#   'wife',
#   'use',
#   'easi',
#   'use',
#   'come',
#   'easi',
#   'read',
#   'guid',
#   'well',
#   'made',
#   'well',
#   'thought',
#   'small',
#   'packag',
#   'store',
#   'easili',
#   'anywher',
#   'item',
#   'arriv',
#   'exactli',
#   'advertis',
#   'far',
#   'im',
#   'pleas',
#   'purchas',
#   'band',
#   'seen',
#   'well',
#   'made',
#   'sturdi',
#   'easi',
#   'use',
#   'switch',
#   'carri',
#   'bag',
#   'plu',
#   'nearli',
#   'hold',
#   'everyth',
#   'nice',
#   'neatli',
#   'awesom',
#   'love',
#   'exercis',
#   'home',
#   'equip',
#   'small',
#   'enough',
#   'tuck',
#   'away',
#   'im',
#   'done',
#   'anchor',
#   'best',
#   'part',
#   'need',
#   'door',
#   'good',
#   'go',
#   'great',
#   'set',
#   'use',
#   'band',
#   '2',
#   'month',
#   'great',
#   'doubl',
#   'shoulder',
#   'bicep',
#   'surgeri',
#   'year',
#   'band',
#   'perfect',
#   'home',
#   'exercis',
#   'prescrib',
#   'physic',
#   'therapist',
#   'use',
#   'mine',
#   'physic',
#   'therapi',
#   'truli',
#   'well',
#   'manufactur',
#   'product',
#   'think',
#   'price',
#   'right',
#   'consid',
#   'level',
#   'excel',
#   'constructioni',
#   'rare',
#   'give',
#   '5',
#   'star',
#   'case',
#   'deserv',
#   'great',
#   'product',
#   'love',
#   'fact',
#   'clip',
#   'multipl',
#   'band',
#   'togeth',
#   'increas',
#   'resist',
#   'great',
#   'quick',
#   'workout',
#   'work',
#   'break',
#   'highli',
#   'recommend',
#   'best',
#   'set',
#   'resist',
#   'band',
#   'amazon',
#   'amaz',
#   'price',
#   'offer',
#   'great',
#   'resist',
#   'provid',
#   'plenti',
#   'exercis',
#   'use',
#   'band',
#   'realli',
#   'great',
#   'qualiti',
#   'equip',
#   'use',
#   'soon',
#   'receiv',
#   'happi',
#   'receiv',
#   'promis',
#   'packag',
#   'well',
#   'nice',
#   'note',
#   'compani',
#   'great',
#   'touch',
#   'awesom',
#   'work',
#   'well',
#   'would',
#   'definit',
#   'buy',
#   'love',
#   'stack',
#   'piec',
#   'hold',
#   'place',
#   'door',
#   'awesom',
#   'best',
#   'purchas',
#   'total',
#   'recommend',
#   'great',
#   'price',
#   'qualiti',
#   'product',
#   'band',
#   'studi',
#   'accessori',
#   'realli',
#   'make',
#   'great',
#   'buy',
#   'great',
#   'addit',
#   'home',
#   'gym',
#   'wow',
#   'complet',
#   'set',
#   'realli',
#   'need',
#   'exercis',
#   'home',
#   'super',
#   'portabl',
#   'take',
#   'travel',
#   'stay',
#   'fit',
#   'black',
#   'mountain',
#   'product',
#   'resist',
#   'band',
#   'set',
#   'door',
#   'anchor',
#   'ankl',
#   'strap',
#   'exercis',
#   'chart',
#   'resist',
#   'band',
#   'carri',
#   'casethi',
#   'resist',
#   'band',
#   'set',
#   'good',
#   'qualiti',
#   'realli',
#   'like',
#   'color',
#   'differ',
#   'weight',
#   'believ',
#   'last',
#   'long',
#   'time',
#   'product',
#   'good',
#   'problem',
#   'didnt',
#   'get',
#   'yellow',
#   'green',
#   'band',
#   'also',
#   'didnt',
#   'get',
#   'manual',
#   'suppos',
#   'includ',
#   'great',
#   'versatil',
#   'way',
#   'exercis',
#   'road',
#   'ive',
#   'use',
#   'month',
#   'complaint',
#   'ive',
#   'product',
#   '6',
#   'month',
#   'use',
#   '2',
#   '3',
#   'time',
#   'per',
#   'week',
#   'theyv',
#   'held',
#   'well',
#   'signific',
#   'wear',
#   'packag',
#   'band',
#   'grip',
#   'ankl',
#   'strap',
#   'door',
#   'strap',
#   'give',
#   'workout',
#   'way',
#   'option',
#   'easi',
#   'storag',
#   'take',
#   'room',
#   'great',
#   'set',
#   'band',
#   'use',
#   'beginn',
#   'manual',
#   'need',
#   'beginn',
#   'great',
#   'purchas',
#   'deilveri',
#   'time',
#   'accur',
#   'bit',
#   'run',
#   'around',
#   'get',
#   'free',
#   'extra',
#   'band',
#   'good',
#   'price',
#   'sturdi',
#   'great',
#   'work',
#   'love',
#   'book',
#   'come',
#   'show',
#   'varieti',
#   'way',
#   'use',
#   'good',
#   'inexpens',
#   'workout',
#   'great',
#   'apart',
#   'dweller',
#   'surpris',
#   'work',
#   'core',
#   'great',
#   'travel',
#   'set',
#   'bag',
#   'nice',
#   'abl',
#   'throw',
#   'travel',
#   'bag',
#   'great',
#   'product',
#   'use',
#   'everi',
#   'day',
#   'conveni',
#   'stackabl',
#   'great',
#   'excus',
#   'great',
#   'qualiti',
#   'product',
#   'work',
#   'would',
#   'buy',
#   'two',
#   'good',
#   'price',
#   'qualiti',
#   'present',
#   'uncomfort',
#   'use',
#   'say',
#   'multipl',
#   'waysstrength',
#   'stretch',
#   'great',
#   'price',
#   'extrem',
#   'sturdi',
#   'set',
#   'didnt',
#   'expect',
#   'level',
#   'qualiti',
#   'impress',
#   'great',
#   'product',
#   'handl',
#   'easi',
#   'switch',
#   'accessori',
#   'great',
#   'surprisingli',
#   'durabl',
#   'work',
#   'perfectli',
#   'im',
#   'happi',
#   'purchas',
#   'great',
#   'set',
#   'band',
#   'use',
#   'daili',
#   'great',
#   'resist',
#   'durabl',
#   'satisfi',
#   'love',
#   'cheaper',
#   'buy',
#   'individu',
#   'band',
#   'perfect',
#   'rehabilit',
#   'use',
#   'shoulder',
#   'perfect',
#   'good',
#   'qualiti',
#   'band',
#   'connector',
#   'work',
#   'properli',
#   'product',
#   'work',
#   'advertis',
#   'recommend',
#   'item',
#   'love',
#   'set',
#   'excel',
#   'qualiti',
#   'easi',
#   'ise',
#   'good',
#   'amount',
#   'ban',
#   'mani',
#   'workout',
#   'good',
#   'valu',
#   'qualiti',
#   'rubber',
#   'band',
#   'vey',
#   'good',
#   'easi',
#   'use',
#   'booklet',
#   'full',
#   'workout',
#   'routin',
#   'love',
#   'product',
#   'good',
#   'qualiti',
#   'price',
#   'great',
#   'resist',
#   'band',
#   'set',
#   'starter',
#   'perfect',
#   'meet',
#   'need',
#   'great',
#   'use',
#   'anywher',
#   'good',
#   'work',
#   'well',
#   'good',
#   'qualiti',
#   'good',
#   '\xc3\xb0'],
#  ['bought',
#   'kit',
#   '2',
#   'winter',
#   'ago',
#   'ranch',
#   'hous',
#   'side',
#   'mountain',
#   'get',
#   'cold',
#   'combin',
#   'realli',
#   'crummi',
#   'old',
#   'window',
#   'hous',
#   'freez',
#   'good',
#   'pay',
#   'home',
#   'heat',
#   'oil',
#   'bad',
#   'one',
#   'point',
#   'windi',
#   'outsid',
#   'actual',
#   'wit',
#   'drape',
#   'hous',
#   'billow',
#   'room',
#   'decid',
#   'purchas',
#   'kit',
#   'actual',
#   'got',
#   '2',
#   'kit',
#   'make',
#   'sure',
#   'could',
#   'finish',
#   'window',
#   'hous',
#   'end',
#   'plenti',
#   'left',
#   'instal',
#   'doubl',
#   'side',
#   'tape',
#   'stuck',
#   'plastic',
#   'use',
#   'blowdryer',
#   'warm',
#   'shrink',
#   'wrap',
#   'window',
#   'done',
#   'draft',
#   'chilli',
#   'room',
#   'suppos',
#   'take',
#   'winter',
#   'left',
#   '2',
#   'year',
#   'find',
#   'also',
#   'keep',
#   'hous',
#   'cooler',
#   'summer',
#   'combin',
#   'thermal',
#   'drape',
#   'combin',
#   'energi',
#   'save',
#   'pro',
#   'stick',
#   'great',
#   'last',
#   'long',
#   'time',
#   'get',
#   'hang',
#   'easi',
#   'instal',
#   'realli',
#   'save',
#   'us',
#   'money',
#   'home',
#   'heat',
#   'oil',
#   'con',
#   'dont',
#   'total',
#   'shrink',
#   'plastic',
#   'see',
#   'rippl',
#   'outsid',
#   'hous',
#   'look',
#   'littl',
#   'messi',
#   'right',
#   'crystal',
#   'clear',
#   'aw',
#   'hard',
#   'get',
#   'doubl',
#   'stick',
#   'tape',
#   'leav',
#   'product',
#   'long',
#   'time',
#   'go',
#   'third',
#   'winter',
#   'kit',
#   'window',
#   'notic',
#   'window',
#   'lose',
#   'plastic',
#   'place',
#   'peel',
#   'etc',
#   'that',
#   'expect',
#   'suppos',
#   'left',
#   'shorter',
#   'period',
#   'time',
#   'apart',
#   'front',
#   'live',
#   'room',
#   'three',
#   'window',
#   'let',
#   'cold',
#   'air',
#   'winter',
#   'move',
#   'live',
#   'room',
#   'middl',
#   'dine',
#   'room',
#   'keep',
#   'door',
#   'two',
#   'room',
#   'open',
#   'enough',
#   'cat',
#   'get',
#   'rare',
#   'go',
#   'front',
#   'room',
#   'winter',
#   'cold',
#   'friend',
#   'help',
#   'instal',
#   'insul',
#   'turn',
#   'easi',
#   'appli',
#   'doublesid',
#   'tape',
#   'around',
#   'frame',
#   'attach',
#   'plastic',
#   'blow',
#   'dri',
#   'heat',
#   'tighten',
#   'plastic',
#   'bare',
#   'even',
#   'see',
#   'insul',
#   'plastic',
#   'problem',
#   'decid',
#   'want',
#   'window',
#   'blind',
#   'plastic',
#   'cover',
#   'entir',
#   'window',
#   'case',
#   'abl',
#   'use',
#   'blind',
#   'shade',
#   'draperi',
#   'ive',
#   'live',
#   'eri',
#   'pa',
#   'seven',
#   'year',
#   'ive',
#   'wast',
#   'much',
#   'money',
#   'ga',
#   'move',
#   'front',
#   'room',
#   'middl',
#   'room',
#   'kept',
#   'door',
#   'two',
#   'ajar',
#   'instead',
#   'wide',
#   'open',
#   'reduc',
#   'monthli',
#   'ga',
#   'budget',
#   '98',
#   '72',
#   'product',
#   'monthli',
#   'amount',
#   '42',
#   'unbeliev',
#   'great',
#   'product',
#   'prevent',
#   'leaki',
#   'window',
#   'succeed',
#   'let',
#   'cold',
#   'air',
#   'insid',
#   'tape',
#   'hold',
#   'well',
#   'outdoor',
#   'wind',
#   'blow',
#   'pleas',
#   'read',
#   'exercis',
#   'patienc',
#   'measur',
#   'twice',
#   'cut',
#   'film',
#   'allow',
#   'extra',
#   'inch',
#   'dont',
#   'skimp',
#   'regret',
#   'read',
#   'tri',
#   'pull',
#   'tight',
#   'mount',
#   'risk',
#   'fit',
#   'tear',
#   'film',
#   'glad',
#   'bought',
#   'one',
#   'extra',
#   'box',
#   'learn',
#   'mistak',
#   'wait',
#   'endur',
#   'cold',
#   'like',
#   'visibl',
#   'outsid',
#   'compromis',
#   'love',
#   'product',
#   'old',
#   'hous',
#   'lot',
#   'leak',
#   'around',
#   'window',
#   'significantli',
#   'chang',
#   'room',
#   'temperatur',
#   'increas',
#   'warmth',
#   'room',
#   'significantli',
#   'took',
#   'us',
#   'one',
#   'window',
#   'figur',
#   'techniqu',
#   'put',
#   'place',
#   'got',
#   'techniqu',
#   'easi',
#   'put',
#   'place',
#   'use',
#   'hair',
#   'dryer',
#   'end',
#   'tighten',
#   'materi',
#   'good',
#   'go',
#   'use',
#   'everi',
#   'winter',
#   'cold',
#   'chicago',
#   'winter',
#   'great',
#   'product',
#   'seal',
#   'great',
#   'definit',
#   'make',
#   'huge',
#   'differ',
#   'temperatur',
#   'heat',
#   'kick',
#   'less',
#   'often',
#   'depend',
#   'window',
#   'size',
#   'sometim',
#   'get',
#   '3',
#   'window',
#   'import',
#   'step',
#   'skip',
#   'make',
#   'sure',
#   'window',
#   'sill',
#   'clean',
#   'insul',
#   'tape',
#   'go',
#   'stick',
#   'cold',
#   'air',
#   'seep',
#   'wast',
#   'money',
#   'first',
#   'let',
#   'state',
#   'product',
#   'may',
#   'work',
#   'ever',
#   'get',
#   'appli',
#   'window',
#   'multipl',
#   'applic',
#   'tri',
#   'center',
#   'giant',
#   'sheet',
#   'saran',
#   'wrap',
#   'around',
#   'super',
#   'sticki',
#   'tape',
#   'probabl',
#   'qualifi',
#   'fuel',
#   'jet',
#   'mid',
#   'air',
#   'product',
#   'beyond',
#   'infuri',
#   'perhap',
#   'team',
#   '4',
#   'would',
#   'issu',
#   'brother',
#   'instal',
#   'use',
#   'hot',
#   'blower',
#   'gun',
#   'sort',
#   'like',
#   'hair',
#   'dryer',
#   'shrunk',
#   'even',
#   'tell',
#   'plastic',
#   'window',
#   'serious',
#   'invis',
#   'tell',
#   'alreadi',
#   'keep',
#   'daylight',
#   'basement',
#   'warmer',
#   'highli',
#   'recommend',
#   'simpl',
#   'solut',
#   'realli',
#   'work',
#   'older',
#   'home',
#   'abl',
#   'afford',
#   'fanci',
#   'new',
#   'window',
#   'immedi',
#   'put',
#   'worst',
#   'problem',
#   'window',
#   'made',
#   'big',
#   'differ',
#   'help',
#   'keep',
#   'room',
#   'much',
#   'warmer',
#   'girlfriend',
#   'room',
#   'garag',
#   'insul',
#   'window',
#   'cut',
#   'cold',
#   'air',
#   'get',
#   'definit',
#   'help',
#   'super',
#   'easi',
#   'use',
#   'never',
#   'need',
#   'use',
#   'window',
#   'insul',
#   'kit',
#   'pleasantli',
#   'surpris',
#   'much',
#   'help',
#   'draft',
#   'come',
#   'window',
#   'us',
#   'work',
#   'couldnt',
#   'get',
#   'tape',
#   'stick',
#   'plastic',
#   'shrink',
#   'us',
#   'wasnt',
#   'good',
#   'buy',
#   'need',
#   'use',
#   'duck',
#   'tape',
#   'lol',
#   'reallt',
#   'easi',
#   'use',
#   'great',
#   'cover',
#   'window',
#   'keep',
#   'cold',
#   'air',
#   'come',
#   'w',
#   'doubl',
#   'side',
#   'tape',
#   'help',
#   'gm\xc3\xa4\xc2\xa3',
#   'care',
#   'use',
#   'pressur',
#   'smooth',
#   'film',
#   'stick',
#   'rub',
#   'fingernail',
#   'tear',
#   'easi',
#   'appli',
#   'kind',
#   'fun',
#   'watch',
#   'contract',
#   'use',
#   'blow',
#   'dryer',
#   'great',
#   'job',
#   'keep',
#   'cold',
#   'air',
#   'old',
#   'good',
#   'keep',
#   'cold',
#   'measur',
#   'first',
#   'clean',
#   'surfac',
#   'properli',
#   'use',
#   'camp',
#   'sticki',
#   'tape',
#   'didnt',
#   'work',
#   'yeah',
#   'im',
#   'pretti',
#   'happi',
#   '3m',
#   'whole',
#   'system',
#   'matter',
#   'size',
#   'bit',
#   'learn',
#   'curv',
#   'get',
#   'lay',
#   'flat',
#   'that',
#   'life',
#   'kid',
#   'ive',
#   'use',
#   'past',
#   '2',
#   'year',
#   'live',
#   'chicago',
#   'cant',
#   'verifi',
#   'due',
#   'chang',
#   'weather',
#   'temp',
#   'ive',
#   'save',
#   'money',
#   'heat',
#   'bill',
#   'id',
#   'like',
#   'think',
#   'well',
#   'worth',
#   'price',
#   'definit',
#   'notic',
#   'draft',
#   'stop',
#   'window',
#   'alway',
#   'ice',
#   'condens',
#   'get',
#   '32\xc2\xba',
#   'ive',
#   'tri',
#   'ceil',
#   'fan',
#   'keep',
#   'air',
#   'flow',
#   'avail',
#   'window',
#   'film',
#   'trick',
#   'everi',
#   'time',
#   'ice',
#   'water',
#   'condens',
#   'window',
#   'sill',
#   'mold',
#   'growth',
#   'moistur',
#   'buy',
#   'put',
#   'stay',
#   'warm',
#   'season',
#   'easi',
#   'use',
#   'work',
#   'great',
#   '5',
#   'differ',
#   'sheet',
#   'materi',
#   '5',
#   'window',
#   'rather',
#   'one',
#   'larg',
#   'sheet',
#   'cut',
#   '5',
#   'piec',
#   'make',
#   'work',
#   '5',
#   'window',
#   'otherwis',
#   'fine',
#   'product',
#   'perfect',
#   'job',
#   'keep',
#   'cold',
#   'air',
#   'around',
#   'ac',
#   'hassl',
#   'remov',
#   'storag',
#   'first',
#   'time',
#   'use',
#   '3m',
#   'window',
#   'insul',
#   'istal',
#   'breez',
#   'scotch',
#   'tape',
#   'held',
#   'like',
#   'champ',
#   'plastic',
#   'clear',
#   'give',
#   'good',
#   'heat',
#   'hair',
#   'dryer',
#   'almost',
#   'feel',
#   'like',
#   'noth',
#   'front',
#   'window',
#   'highli',
#   'recommend',
#   'cold',
#   'weather',
#   'heat',
#   'good',
#   'hour',
#   'day',
#   'night'],
#  ['purchas',
#   'fire',
#   'extinguish',
#   '2001',
#   'sat',
#   'kitchen',
#   'counter',
#   'ever',
#   'sinc',
#   'march',
#   '17th',
#   '2012',
#   'next',
#   'door',
#   'neighbor',
#   'outsid',
#   'hous',
#   'foolishli',
#   'pour',
#   'gasolin',
#   'full',
#   '25gallon',
#   'contain',
#   'onto',
#   'pile',
#   'hot',
#   'smolder',
#   'wooden',
#   'log',
#   'cours',
#   'explod',
#   'land',
#   'outsid',
#   '2stori',
#   'hous',
#   'hous',
#   'wood',
#   'frame',
#   'hous',
#   'paint',
#   'wood',
#   'side',
#   'point',
#   'fire',
#   'roll',
#   'ground',
#   'put',
#   'end',
#   '3rd',
#   'degre',
#   'burn',
#   'next',
#   'action',
#   'get',
#   'come',
#   'find',
#   'work',
#   'outsid',
#   'rake',
#   'leav',
#   'heard',
#   'scream',
#   'time',
#   'fire',
#   'rage',
#   'outsid',
#   'hous',
#   'flame',
#   '810',
#   'wide',
#   'side',
#   'hous',
#   'touch',
#   'top',
#   '2nd',
#   'stori',
#   'gutter',
#   'panick',
#   'call',
#   '911',
#   'quickli',
#   'retriev',
#   'small',
#   'kiddi',
#   'fire',
#   'extinguish',
#   'kitchen',
#   'ran',
#   'toward',
#   'blaze',
#   'point',
#   'think',
#   'shoot',
#   'bbgun',
#   'read',
#   'everi',
#   'car',
#   'reason',
#   'one',
#   'even',
#   'drive',
#   'citi',
#   'daili',
#   'commut',
#   'could',
#   'mean',
#   'differ',
#   'save',
#   'car',
#   'life',
#   '2',
#   'jeep',
#   'especi',
#   'road',
#   'purchas',
#   'crazi',
#   'nye',
#   'night',
#   'took',
#   'two',
#   'thing',
#   'put',
#   'trash',
#   'fire',
#   'garag',
#   'must',
#   'middl',
#   'age',
#   'man',
#   'want',
#   'save',
#   'face',
#   'put',
#   'fire',
#   'use',
#   'fire',
#   'work',
#   'garbag',
#   'great',
#   'fire',
#   'extinguish',
#   'great',
#   'price',
#   'came',
#   'broken',
#   'wall',
#   'strap',
#   'make',
#   'imposs',
#   'secur',
#   'wall',
#   'disappoint',
#   'mayb',
#   'shelf',
#   'long',
#   'plastic',
#   'got',
#   'brittl',
#   'ever',
#   'sinc',
#   'fire',
#   'neighborhood',
#   'start',
#   'make',
#   'precaut',
#   'prevent',
#   'fire',
#   'that',
#   'ive',
#   'buy',
#   'fire',
#   'extinguish',
#   'well',
#   'never',
#   'would',
#   'need',
#   'use',
#   'never',
#   'mani',
#   'safeti',
#   'item',
#   'home',
#   'car',
#   'offic',
#   'wont',
#   'put',
#   'forest',
#   'fire',
#   'nice',
#   'thing',
#   'eas',
#   'mind',
#   'offer',
#   'havent',
#   'use',
#   'yet',
#   'howev',
#   'make',
#   'feel',
#   'safer',
#   'honestli',
#   'price',
#   'everyon',
#   'get',
#   'one',
#   'case',
#   'situat',
#   'hasnt',
#   'use',
#   'sure',
#   'job',
#   'feel',
#   'like',
#   'substanti',
#   'product',
#   'price',
#   'less',
#   'lot',
#   'hardwar',
#   'store',
#   'appear',
#   'solid',
#   'built',
#   'fire',
#   'extinguish',
#   'fortun',
#   'havent',
#   'use',
#   'hope',
#   'never',
#   'arriv',
#   'fulli',
#   'charg',
#   'neatli',
#   'pack',
#   'wall',
#   'hang',
#   'unit',
#   'fit',
#   'kitchen',
#   'sink',
#   'fire',
#   'extinguish',
#   'fulli',
#   'discharg',
#   'upon',
#   'open',
#   'packag',
#   'mess',
#   'outstand',
#   'product',
#   'price',
#   'freaki',
#   'fast',
#   'deliveri',
#   'good',
#   'home',
#   'old',
#   'man',
#   'take',
#   'chanc',
#   'need',
#   'home',
#   'good',
#   'item',
#   'household',
#   'bought',
#   'gift',
#   'defect',
#   'work',
#   'unbeliev',
#   'defect',
#   'safeti',
#   'equip',
#   'sold',
#   'still',
#   'avail',
#   'purchas',
#   'effort',
#   'made',
#   'warn',
#   'peopl',
#   'bought',
#   'great'],
#  ['perfect',
#   'brush',
#   'clean',
#   'hydroflask',
#   'previous',
#   'use',
#   'babi',
#   'bottl',
#   'brush',
#   'find',
#   'one',
#   'better',
#   'purchas',
#   'bottl',
#   'scrubber',
#   'clean',
#   'glass',
#   'water',
#   'bottl',
#   'dont',
#   'feel',
#   'come',
#   'super',
#   'clean',
#   'dishwash',
#   'brush',
#   'work',
#   'fine',
#   'one',
#   'bottl',
#   'bristl',
#   'stuff',
#   'hope',
#   'flexibl',
#   'brush',
#   'good',
#   'qualiti',
#   'though',
#   'feel',
#   'like',
#   'last',
#   'long',
#   'time',
#   'fit',
#   'nook',
#   'cranni',
#   'bottl',
#   'breast',
#   'pump',
#   'part',
#   'greatli',
#   'assist',
#   'effici',
#   'clean',
#   '4star',
#   'rate',
#   'purpos',
#   'handl',
#   'neck',
#   'bit',
#   'long',
#   'stand',
#   'brush',
#   'bit',
#   'awkward',
#   'store',
#   'kitchen',
#   'otherwis',
#   'great',
#   'product',
#   'price',
#   'well',
#   'perfect',
#   'brush',
#   'nalgen',
#   'bottl',
#   'get',
#   'wide',
#   'mouth',
#   'smaller',
#   'water',
#   'bottl',
#   'size',
#   'mouth',
#   'one',
#   'get',
#   'wreck',
#   'vigor',
#   'clean',
#   'ill',
#   'sure',
#   'pick',
#   'anoth',
#   'use',
#   'wash',
#   'soda',
#   'stream',
#   'bottl',
#   'work',
#   'great',
#   'second',
#   'time',
#   'purchas',
#   'product',
#   'use',
#   'first',
#   'one',
#   'end',
#   'lifespan',
#   'perfect',
#   'length',
#   'qualiti',
#   'product',
#   'use',
#   'clean',
#   'grow',
#   'collect',
#   'swell',
#   'bottl',
#   'good',
#   'length',
#   'reach',
#   'bottom',
#   '24oz',
#   'swell',
#   'got',
#   'clean',
#   'soda',
#   'stream',
#   'bottl',
#   'perfect',
#   'size',
#   'super',
#   'soft',
#   'bristl',
#   'wand',
#   'part',
#   'fo',
#   'handl',
#   'nice',
#   'flexibl',
#   'great',
#   'glass',
#   'also',
#   'use',
#   'brush',
#   'sensit',
#   'pan',
#   'avoid',
#   'scratch',
#   'look',
#   'brush',
#   'like',
#   'one',
#   'pan',
#   'dish',
#   'last',
#   'month',
#   'clean',
#   'water',
#   'bottl',
#   'bought',
#   'work',
#   'well',
#   'felt',
#   'good',
#   'water',
#   'bottl',
#   'good',
#   'clean',
#   'handl',
#   'could',
#   'littl',
#   'sturdi',
#   'otherwis',
#   'like',
#   'product',
#   'reach',
#   'clean',
#   'bottl',
#   'insid',
#   'well',
#   'one',
#   'best',
#   'bottl',
#   'brush',
#   'ive',
#   'use',
#   'work',
#   'wonder',
#   'clean',
#   'nalgen',
#   '1000ml',
#   'water',
#   'bottl',
#   'left',
#   'hot',
#   'water',
#   'sink',
#   'deform',
#   'bristl',
#   'get',
#   'return',
#   'shape',
#   'sturdi',
#   'bristl',
#   'scrub',
#   'well',
#   'fit',
#   'open',
#   'handl',
#   'good',
#   'length',
#   'brush',
#   'work',
#   'great',
#   'hydro',
#   'flask',
#   'buy',
#   'anoth',
#   'one',
#   'use',
#   'far',
#   'great',
#   '8',
#   'week',
#   'usag',
#   'problem',
#   'recommend',
#   'excel',
#   'brush',
#   'use',
#   'oxo',
#   'electr',
#   'tea',
#   'kettl',
#   'made',
#   'mostli',
#   'glass',
#   'total',
#   'awesom',
#   'mean',
#   'wash',
#   'insid',
#   'sport',
#   'drink',
#   'bottl',
#   'stain',
#   'surprisingli',
#   'easili',
#   'leav',
#   'look',
#   'dirti',
#   'time',
#   'would',
#   'buy',
#   'give',
#   'gift',
#   'great',
#   'clean',
#   'hard',
#   'get',
#   'place',
#   'handl',
#   'bit',
#   'short',
#   'otherwis',
#   'good',
#   'product',
#   'work',
#   'great',
#   'think',
#   'use',
#   'around',
#   'year',
#   'good',
#   'tool',
#   'wish',
#   'bristl',
#   'tough',
#   'nice',
#   'qualiti',
#   'taken',
#   'everyon',
#   'els',
#   'nice',
#   'brush',
#   'would',
#   'prefer',
#   'stiffer',
#   'bristl',
#   'good',
#   'product',
#   'fast',
#   'ship',
#   'excel',
#   'buy',
#   'nice',
#   'soft',
#   'brush',
#   'good',
#   'nonstick',
#   'pan',
#   'perfect',
#   'clean',
#   'swell',
#   'bottl',
#   'good',
#   'grip',
#   'non',
#   'shed',
#   'bottl',
#   'brush',
#   'great',
#   'tight',
#   'spot',
#   'clean',
#   'well',
#   'great',
#   'price',
#   'good',
#   'littl',
#   'brush',
#   'clean',
#   'mason',
#   'jar',
#   'well',
#   'use',
#   'work',
#   'well',
#   'work',
#   'expect',
#   'qualiti',
#   'product',
#   'expect',
#   'work',
#   'decent',
#   'super',
#   'cheap',
#   'sturdi',
#   'dont',
#   'work',
#   'perfect',
#   'work',
#   'nice',
#   'perfect',
#   'perfect'],
#  ['check',
#   'product',
#   'detail',
#   'packag',
#   'mine',
#   'arriv',
#   'differ',
#   'advertis',
#   'advertis',
#   'packag',
#   'specif',
#   'say',
#   'origin',
#   'us',
#   'packag',
#   'yet',
#   'mine',
#   'complet',
#   'differ',
#   'shape',
#   'form',
#   'design',
#   'problem',
#   'addit',
#   'fact',
#   'infus',
#   'display',
#   'wear',
#   'tear',
#   'symptomat',
#   'use',
#   'despit',
#   'fact',
#   'purchas',
#   'new',
#   'like',
#   'design',
#   'qualiti',
#   'bad',
#   'use',
#   '5',
#   'day',
#   'week',
#   'chain',
#   'detach',
#   'third',
#   'time',
#   'well',
#   'that',
#   'big',
#   'deal',
#   'got',
#   'much',
#   'metal',
#   'rusti',
#   'thought',
#   'tea',
#   'stain',
#   'whitin',
#   'one',
#   'month',
#   'dont',
#   'feel',
#   'safe',
#   'doesnt',
#   'close',
#   'properli',
#   'loos',
#   'leaf',
#   'tea',
#   'use',
#   'alway',
#   'come',
#   'water',
#   'pick',
#   'lot',
#   'definit',
#   'look',
#   'better',
#   'one',
#   'crap',
#   'close',
#   'still',
#   'massiv',
#   'gap',
#   'largest',
#   'tea',
#   'piec',
#   'float',
#   'might',
#   'well',
#   'dump',
#   'loos',
#   'leaf',
#   'tea',
#   'right',
#   'water',
#   'would',
#   'good',
#   'money',
#   'realli',
#   'cant',
#   'complain',
#   'tea',
#   'ball',
#   'thing',
#   'doesnt',
#   'shut',
#   'way',
#   'everi',
#   'cup',
#   'tea',
#   'linger',
#   'loos',
#   'leav',
#   'within',
#   'easi',
#   'clasp',
#   'open',
#   'hook',
#   'latch',
#   'onto',
#   'cup',
#   'handl',
#   'also',
#   'tell',
#   'much',
#   'tea',
#   'cup',
#   'handi',
#   'new',
#   'loos',
#   'leaf',
#   'game',
#   'bag',
#   'awesom',
#   'first',
#   'time',
#   'shop',
#   'reusabl',
#   'bag',
#   'pick',
#   'winner',
#   'even',
#   'checker',
#   'ask',
#   'got',
#   'love',
#   '\xc3\xb0\xc3\xb0',
#   '\xc2\xbb',
#   'great',
#   'practic',
#   'stainless',
#   'steel',
#   'mesh',
#   'ball',
#   'perfect',
#   'size',
#   'materi',
#   'doesnt',
#   'leav',
#   'tast',
#   'beverag',
#   'would',
#   'recommend',
#   'use',
#   'regularli',
#   'month',
#   'still',
#   'like',
#   'new',
#   'condit',
#   'issu',
#   'tea',
#   'leav',
#   'fall',
#   'steep',
#   'bought',
#   'make',
#   'larg',
#   'portion',
#   'loos',
#   'leaf',
#   'tea',
#   'leav',
#   'fall',
#   'side',
#   'tea',
#   'rare',
#   'use',
#   'lost',
#   'lip',
#   'clip',
#   'link',
#   'loos',
#   'end',
#   'chain',
#   'mayb',
#   '3',
#   'day',
#   'work',
#   'great',
#   'point',
#   'ive',
#   'use',
#   'product',
#   'reliabl',
#   'mani',
#   'year',
#   'start',
#   'rust',
#   'great',
#   'product',
#   'awesom',
#   'qualiti',
#   'great',
#   'companion',
#   'tea',
#   'clasp',
#   'broke',
#   'coupl',
#   'month',
#   'render',
#   'unus',
#   'broke',
#   'use',
#   'flimsi',
#   'ship',
#   'slow',
#   'product',
#   'work',
#   'disappoint',
#   'buy',
#   'loos',
#   'teawork',
#   'like',
#   'charmeasi',
#   'clean',
#   'rusti',
#   'hard',
#   'clean',
#   'use',
#   'high',
#   'qualiti',
#   'work',
#   'easi',
#   'use',
#   'work',
#   'well',
#   'easi',
#   'clean',
#   'broke',
#   'made',
#   'mug',
#   'well',
#   'made',
#   'sturdi',
#   'work',
#   'great',
#   'awkward',
#   'work',
#   'work',
#   'leaf',
#   'tea',
#   'great',
#   'small',
#   'bad',
#   'materi',
#   'great',
#   'item',
#   'fast',
#   'deleveri',
#   'work',
#   'realli',
#   'good',
#   'wonder',
#   'product',
#   'good',
#   'product',
#   'work',
#   'great',
#   'break',
#   'fast',
#   'perfect',
#   'love',
#   'love',
#   'good',
#   'love',
#   'watch',
#   'tea',
#   'spread',
#   'love',
#   'make',
#   'tea',
#   'littl',
#   'bit',
#   'nicer'],
#  ['couldnt',
#   'live',
#   'without',
#   'tool',
#   'kitchen',
#   'zest',
#   'grate',
#   'regularli',
#   'microplan',
#   'easi',
#   'reach',
#   'essenti',
#   'sever',
#   'style',
#   'microplan',
#   'grate',
#   'differ',
#   'thing',
#   'differ',
#   'size',
#   'one',
#   'use',
#   'lime',
#   'lemon',
#   'orang',
#   'etc',
#   'fit',
#   'right',
#   'dishwash',
#   'done',
#   'alway',
#   'sharp',
#   'use',
#   'replac',
#   'one',
#   'mani',
#   'year',
#   'final',
#   'gotten',
#   'littl',
#   'dull',
#   'ten',
#   'year',
#   'essenti',
#   'daili',
#   'use',
#   'guess',
#   'allow',
#   'sharp',
#   'microplan',
#   'great',
#   'grater',
#   'bought',
#   'planer',
#   'advic',
#   'daughter',
#   'whose',
#   'kitchen',
#   'philosophi',
#   'gadget',
#   'make',
#   'high',
#   'qualiti',
#   'grater',
#   'planer',
#   'work',
#   'well',
#   'typic',
#   'use',
#   'zest',
#   'lemon',
#   'grate',
#   'parmesan',
#   'chees',
#   'job',
#   'perfectli',
#   'easi',
#   'clean',
#   'nowi',
#   'buy',
#   'chees',
#   'block',
#   'better',
#   'cheaper',
#   'keep',
#   'longer',
#   'becom',
#   'one',
#   'favorit',
#   'kitchen',
#   'tool',
#   'use',
#   'easili',
#   'grate',
#   'garlic',
#   'fine',
#   'consist',
#   'almost',
#   'melt',
#   'soup',
#   'sauc',
#   'also',
#   'perfect',
#   'get',
#   'zest',
#   'lemon',
#   'orang',
#   'delight',
#   'versatil',
#   'tool',
#   'absolut',
#   'worth',
#   'microplan',
#   'fantast',
#   'use',
#   'everi',
#   'day',
#   'great',
#   'minc',
#   'garlic',
#   'zest',
#   'lemon',
#   'lime',
#   'grate',
#   'chees',
#   'etc',
#   'bought',
#   'addit',
#   'one',
#   'friend',
#   'famili',
#   'great',
#   'buy',
#   'must',
#   'need',
#   'zester',
#   'easi',
#   'use',
#   'make',
#   'fast',
#   'work',
#   'citru',
#   'peel',
#   'quickli',
#   'add',
#   'citru',
#   'zest',
#   'clean',
#   'easi',
#   'storag',
#   'slim',
#   'item',
#   'easi',
#   'love',
#   'purchas',
#   'one',
#   'back',
#   'love',
#   'much',
#   'got',
#   'one',
#   'daughter',
#   'reason',
#   'price',
#   'qualiti',
#   'nice',
#   'well',
#   'weve',
#   'two',
#   'year',
#   'mani',
#   'microplan',
#   'fell',
#   'apart',
#   'one',
#   'great',
#   'use',
#   'time',
#   'wish',
#   'slightli',
#   'easier',
#   'clean',
#   'love',
#   'microplan',
#   'use',
#   'mostli',
#   'citru',
#   'zest',
#   'parmasen',
#   'chees',
#   'pasta',
#   'dishwash',
#   'safe',
#   'sharp',
#   'though',
#   'care',
#   'first',
#   'time',
#   'use',
#   'end',
#   'littl',
#   'bit',
#   'much',
#   'finger',
#   'finger',
#   'food',
#   'know',
#   'mean',
#   'watch',
#   'love',
#   'zester',
#   'give',
#   'type',
#   'zest',
#   'need',
#   'without',
#   'mush',
#   'well',
#   'made',
#   'hard',
#   'clean',
#   'realli',
#   'work',
#   'perfect',
#   'receip',
#   'call',
#   'bit',
#   'lemon',
#   'lime',
#   'ginger',
#   'etc',
#   'zest',
#   'larger',
#   'thought',
#   'would',
#   'larger',
#   'shave',
#   'wanted\xc3\xb0\xc2\xb6',
#   'dose',
#   'work',
#   'well',
#   'perfect',
#   'exactli',
#   'look',
#   'perfect',
#   'zest',
#   'lemon',
#   'shred',
#   'nutmeg',
#   'best',
#   'grater',
#   'ever',
#   'super',
#   'fine',
#   'grateperfect',
#   'fruit',
#   'zest',
#   'hard',
#   'chees',
#   'great',
#   'qualiti',
#   'wish',
#   'research',
#   'item',
#   'buy',
#   'one',
#   'ive',
#   'around',
#   'year',
#   'complaint',
#   'work',
#   'well',
#   'cant',
#   'believ',
#   'ive',
#   'wait',
#   'long',
#   'order',
#   'one',
#   'use',
#   'time',
#   'love',
#   'thing',
#   'perfect',
#   'zest',
#   'grate',
#   'cheesespic',
#   'sharp',
#   'dont',
#   'know',
#   'taken',
#   'long',
#   'get',
#   'one',
#   'awesom',
#   'kitchen',
#   'tool',
#   'love',
#   'know',
#   'live',
#   'without',
#   'mani',
#   'year',
#   'nice',
#   'product',
#   'everi',
#   'kitchen',
#   'one',
#   'sharp',
#   'grate',
#   'hard',
#   'chees',
#   'fruit',
#   'zest',
#   'good',
#   'cheap',
#   'grater',
#   'suppos',
#   'price',
#   'right',
#   'save',
#   'much',
#   'time',
#   'need',
#   'littl',
#   'lemon',
#   'zest',
#   'recip',
#   'terrif',
#   'zesterveri',
#   'sharp',
#   'easi',
#   'remov',
#   'zest',
#   'help',
#   'shred',
#   'chees',
#   'eas',
#   'kinda',
#   'hard',
#   'clean',
#   'sometim',
#   'dont',
#   'even',
#   'know',
#   'got',
#   'credit',
#   'damag',
#   'product',
#   'sent',
#   'work',
#   'great',
#   'ginger',
#   'turmer',
#   'root',
#   'love',
#   'broke',
#   'three',
#   'use',
#   'handl',
#   'separ',
#   'metal',
#   'use',
#   'mani',
#   'grater',
#   'one',
#   'best',
#   'want',
#   'great',
#   'zester',
#   'one',
#   'good',
#   'qualiti',
#   'sturdi',
#   'easi',
#   'use',
#   'great',
#   'zest',
#   'lemon',
#   'limoncello',
#   'excel',
#   'zester',
#   'happi',
#   'bought',
#   'tho',
#   'havent',
#   'use',
#   'yet',
#   'look',
#   'great',
#   'meet',
#   'expect',
#   'work',
#   'great',
#   'expect',
#   'must',
#   'kitchen',
#   'qualiti',
#   'product',
#   'great',
#   'qualiti',
#   'excel',
#   'great'],
#  ['son',
#   'wore',
#   'first',
#   'one',
#   'work',
#   'great',
#   'without',
#   'problem',
#   'one',
#   'got',
#   'niecesh',
#   'thrill',
#   'wonder',
#   'accessori',
#   'use',
#   'regularli',
#   'great',
#   'qualiti',
#   'exactli',
#   'need',
#   'qualiti',
#   'great',
#   'work',
#   'great',
#   'unit',
#   'easi',
#   'clean',
#   'work',
#   'better',
#   'way',
#   'expens',
#   'one',
#   'work',
#   'great',
#   'venison',
#   'great'],
#  ['key',
#   'good',
#   'coffe',
#   'spice',
#   'grinder',
#   'nonov',
#   'nonellipt',
#   'interior',
#   'kick',
#   'spice',
#   'blade',
#   'krup',
#   'add',
#   'flat',
#   'side',
#   'cap',
#   'interior',
#   'grind',
#   'well',
#   'krup',
#   'make',
#   'cap',
#   'cheap',
#   'brittl',
#   'plastic',
#   'spontan',
#   'crack',
#   'normal',
#   'use',
#   'patch',
#   'first',
#   'crack',
#   'other',
#   'kept',
#   'come',
#   'alreadi',
#   'five',
#   'three',
#   'month',
#   'use',
#   'mean',
#   'cap',
#   'sooner',
#   'rather',
#   'later',
#   'break',
#   'apart',
#   'see',
#   'photo',
#   'amazon',
#   'price',
#   '1999',
#   'bought',
#   'mine',
#   'bed',
#   'bath',
#   'beyond',
#   'coupon',
#   'brought',
#   'price',
#   '1500',
#   'pro',
#   'cheap',
#   'power',
#   'motor',
#   'blade',
#   'con',
#   'uneven',
#   'grind',
#   'smallish',
#   'capac',
#   'your',
#   'look',
#   'coffe',
#   'grinder',
#   'wouldnt',
#   'recommend',
#   'blade',
#   'one',
#   'especi',
#   'care',
#   'use',
#   'right',
#   'size',
#   'grind',
#   'right',
#   'drink',
#   'blade',
#   'grinder',
#   'cheap',
#   'burr',
#   'grinder',
#   'ensur',
#   'uniform',
#   'grind',
#   'import',
#   'get',
#   'consist',
#   'flavor',
#   'brew',
#   'grinder',
#   'howev',
#   'would',
#   'perfect',
#   'spice',
#   'would',
#   'actual',
#   'recommend',
#   'use',
#   'clean',
#   'rel',
#   'easi',
#   'use',
#   'damp',
#   'paper',
#   'towel',
#   'wipe',
#   'remain',
#   'dri',
#   'one',
#   'finish',
#   'job',
#   'got',
#   'parent',
#   'love',
#   'coffe',
#   'didnt',
#   'realli',
#   'like',
#   'product',
#   'actual',
#   'went',
#   'back',
#   'old',
#   'coffe',
#   'grinder',
#   'someth',
#   'bean',
#   'werent',
#   'grind',
#   'well',
#   'someth',
#   'im',
#   'guess',
#   'product',
#   'isnt',
#   'realli',
#   'coffe',
#   'addict',
#   'thing',
#   'grind',
#   'ground',
#   'everyth',
#   'place',
#   'eas',
#   'bad',
#   'stuff',
#   'unit',
#   'realli',
#   'realli',
#   'hard',
#   'clean',
#   'way',
#   'keep',
#   'clean',
#   'wash',
#   'everi',
#   'use',
#   'use',
#   'grind',
#   'food',
#   'dehydr',
#   'powder',
#   'sweet',
#   'pepper',
#   'carrot',
#   'kale',
#   'beet',
#   'lime',
#   'ginger',
#   'turbinado',
#   'sugar',
#   'use',
#   'clean',
#   'big',
#   'chore',
#   'due',
#   'napkin',
#   'bought',
#   'brush',
#   'clean',
#   'isnt',
#   'best',
#   'thing',
#   'need',
#   'put',
#   'water',
#   'get',
#   'dust',
#   'bottom',
#   'blade',
#   'unit',
#   'seem',
#   'waterproof',
#   'tri',
#   'find',
#   'shoot',
#   'water',
#   'lid',
#   'learn',
#   'realli',
#   'fast',
#   'place',
#   'small',
#   'amount',
#   'time',
#   'allow',
#   'particl',
#   'stuck',
#   'blade',
#   'remov',
#   'unit',
#   'surprisingli',
#   'heavi',
#   'use',
#   'stop',
#   'work',
#   'shake',
#   'would',
#   'turn',
#   'believ',
#   'stop',
#   'work',
#   'due',
#   'lid',
#   'way',
#   'want',
#   'process',
#   'coffe',
#   'bean',
#   'least',
#   'see',
#   'end',
#   'result',
#   'experi',
#   'dont',
#   'know',
#   'anyon',
#   'could',
#   'get',
#   'anyth',
#   'fine',
#   'grind',
#   'seem',
#   'powder',
#   'everyth',
#   'second',
#   'second',
#   'see',
#   'powder',
#   'form',
#   'lid',
#   'idea',
#   'would',
#   'get',
#   'coars',
#   'grind',
#   'krup',
#   'mayb',
#   'result',
#   'differ',
#   'coffe',
#   'bean',
#   'dehydr',
#   'food',
#   'imagin',
#   'would',
#   'puls',
#   'longer',
#   'second',
#   'exactli',
#   'look',
#   'though',
#   'end',
#   'give',
#   '5',
#   'star',
#   'replac',
#   'realli',
#   'old',
#   'grinder',
#   'similar',
#   'type',
#   'cusinart',
#   'one',
#   'work',
#   'great',
#   'like',
#   'sinc',
#   'larger',
#   'capac',
#   'bean',
#   'grind',
#   'cours',
#   'grind',
#   'depend',
#   'long',
#   'hold',
#   'button',
#   'like',
#   'mine',
#   'ground',
#   'fine',
#   'espresso',
#   'machin',
#   'powder',
#   'tend',
#   'cake',
#   'blade',
#   'develop',
#   'habit',
#   'hold',
#   'push',
#   'button',
#   'tilt',
#   'sideway',
#   'back',
#   'forth',
#   'grind',
#   'facilit',
#   'mix',
#   'one',
#   'would',
#   'well',
#   'count',
#   'second',
#   'grind',
#   'like',
#   'consist',
#   'time',
#   'believ',
#   'take',
#   '10',
#   'second',
#   'get',
#   'fine',
#   'enough',
#   'grind',
#   'done',
#   'put',
#   'gound',
#   'coffe',
#   'small',
#   'make',
#   'day',
#   'two',
#   'worth',
#   'one',
#   'time',
#   'alway',
#   'fresh',
#   'one',
#   'need',
#   'use',
#   'finger',
#   'anoth',
#   'object',
#   'get',
#   'cake',
#   'product',
#   'bottom',
#   'big',
#   'deal',
#   'easi',
#   'clean',
#   'paper',
#   'towel',
#   'around',
#   'insid',
#   'tap',
#   'remaind',
#   'found',
#   'small',
#   'brush',
#   'use',
#   'get',
#   'grind',
#   'crevass',
#   'overal',
#   'find',
#   'great',
#   'valu',
#   'work',
#   'well',
#   'small',
#   'portion',
#   'buy',
#   'use',
#   'whole',
#   'spice',
#   'health',
#   'food',
#   'store',
#   'fresher',
#   'cheaper',
#   'packag',
#   'spice',
#   'groceri',
#   'shelv',
#   'allow',
#   'flexibl',
#   'purchas',
#   'exact',
#   'amount',
#   'particular',
#   'recip',
#   'without',
#   'wast',
#   'unus',
#   'portion',
#   'instead',
#   'buy',
#   'individu',
#   'spice',
#   'mill',
#   'want',
#   'one',
#   'mill',
#   'could',
#   'type',
#   'grind',
#   'coars',
#   'fine',
#   'went',
#   'america',
#   'tedt',
#   'kitchen',
#   'websit',
#   'read',
#   'review',
#   'product',
#   '5',
#   'star',
#   'rate',
#   'know',
#   'could',
#   'trust',
#   'experi',
#   'review',
#   'purchas',
#   'mill',
#   'livesup',
#   'claim',
#   'remov',
#   'cup',
#   'easi',
#   'pour',
#   'clean',
#   'spice',
#   'mill',
#   'need',
#   'ye',
#   'awesom',
#   'coffe',
#   'bean',
#   'nut',
#   'etc',
#   'highli',
#   'recommend',
#   'product',
#   'easi',
#   'quick',
#   'produc',
#   'even',
#   'grind',
#   'mission',
#   'replac',
#   'last',
#   'coffe',
#   'bean',
#   'grinder',
#   'spent',
#   'consider',
#   'time',
#   'read',
#   'review',
#   'toprat',
#   'one',
#   'final',
#   'decid',
#   'one',
#   'big',
#   'mistak',
#   'krup',
#   'f203',
#   'inde',
#   'grind',
#   'coffe',
#   'bean',
#   'tri',
#   'transfer',
#   'ground',
#   'one\xc3\xa2',
#   'coffe',
#   'maker',
#   'result',
#   'huge',
#   'mess',
#   'wouldn\xc3\xa2t',
#   'know',
#   'perhap',
#   'highli',
#   'rate',
#   'grinder',
#   'would',
#   'appropri',
#   'grind',
#   'spice',
#   'it\xc3\xa2',
#   'way',
#   'messi',
#   'daili',
#   'grind',
#   'coffe',
#   'bean',
#   'summari',
#   'quit',
#   'grind',
#   'coffe',
#   'bean',
#   'shortli',
#   'start',
#   'use',
#   'grinder',
#   'thank',
#   'purchas',
#   'i\xc3\xa2m',
#   'back',
#   'buy',
#   'preground',
#   'coffe',
#   'gim',
#   'old',
#   'grinder',
#   'back',
#   'recommend',
#   'review',
#   'buy',
#   'first',
#   'ever',
#   'coffe',
#   'grinder',
#   'chose',
#   'one',
#   'low',
#   'cost',
#   'compact',
#   'design',
#   'fantast',
#   'addit',
#   'kitchen',
#   'fresh',
#   'ground',
#   'coffe',
#   'everi',
#   'day',
#   'delici',
#   'incred',
#   'easi',
#   'use',
#   'noisi',
#   'compact',
#   'tuck',
#   'away',
#   'corner',
#   'take',
#   'space',
#   'complaint',
#   'fairli',
#   'easi',
#   'spill',
#   'counter',
#   'open',
#   'top',
#   'your',
#   'done',
#   'grind',
#   'im',
#   'sure',
#   'univers',
#   'problem',
#   'grinder',
#   'design',
#   'one',
#   'tri',
#   'extra',
#   'care',
#   'minim',
#   'spillag',
#   'happi',
#   'chose',
#   'grinder',
#   'look',
#   'grinder',
#   'realiz',
#   'import',
#   'get',
#   'one',
#   'grind',
#   'first',
#   'cup',
#   'bean',
#   'omg',
#   'littl',
#   'machin',
#   'unbeat',
#   'like',
#   'ferrari',
#   'grinder',
#   '5',
#   'second',
#   'perfect',
#   'ground',
#   'blend',
#   'readi',
#   'make',
#   'day',
#   'start',
#   'bang',
#   'use',
#   'militari',
#   'actual',
#   'stunk',
#   'slow',
#   'got',
#   'stuck',
#   'one',
#   'one',
#   'take',
#   'mundan',
#   'task',
#   'make',
#   'extra',
#   'ordinari',
#   'use',
#   'krup',
#   'rest',
#   'life',
#   'doubt',
#   'grind',
#   'cup',
#   'remov',
#   'product',
#   'difficult',
#   'clean',
#   'turn',
#   'grinder',
#   'upsid',
#   'tap',
#   'spoon',
#   'get',
#   'ground',
#   'coffe',
#   'grind',
#   'chamber',
#   'resid',
#   'coffe',
#   'left',
#   'lid',
#   'well',
#   'chamber',
#   'adjust',
#   'grind',
#   'top',
#   'difficult',
#   'remov',
#   'time',
#   'use',
#   'damp',
#   'paper',
#   'towel',
#   'clean',
#   'unit',
#   'everi',
#   'time',
#   'use',
#   'pain',
#   'pro',
#   'easi',
#   'use',
#   'compact',
#   'design',
#   'reason',
#   'price',
#   'con',
#   'use',
#   'grind',
#   'spice',
#   'suggest',
#   'use',
#   'coffe',
#   'get',
#   'consist',
#   'texturegrain',
#   'size',
#   'buy',
#   'burr',
#   'grinder',
#   'coffe',
#   'bean',
#   'instead',
#   'difficult',
#   'clean',
#   'blade',
#   'fulli',
#   'especi',
#   'underneath',
#   'blade',
#   'youll',
#   'use',
#   'pipe',
#   'cleaner',
#   'thin',
#   'piec',
#   'fabric',
#   'wish',
#   'list',
#   'got',
#   'christma',
#   'fathernlaw',
#   'love',
#   'coffe',
#   'love',
#   'strang',
#   'brew',
#   'world',
#   'differ',
#   'coffe',
#   'maker',
#   'come',
#   'great',
#   'use',
#   'give',
#   'coffe',
#   'ground',
#   'first',
#   'batch',
#   'alreadi',
#   'didnt',
#   'grind',
#   'whole',
#   'bag',
#   'ruin',
#   'flavr',
#   'bean',
#   'bought',
#   'one',
#   'replac',
#   'earlier',
#   'model',
#   'id',
#   'use',
#   'sinc',
#   '1978',
#   'earlier',
#   'model',
#   'still',
#   'work',
#   'well',
#   'look',
#   'aw',
#   'year',
#   'use',
#   'accid',
#   'expect',
#   'model',
#   'last',
#   'long',
#   'certainli',
#   'job',
#   'well',
#   'detect',
#   'loss',
#   'qualiti',
#   'earlier',
#   'model',
#   'use',
#   'mine',
#   'grind',
#   'spice',
#   'occasion',
#   'grind',
#   'coffe',
#   'bean',
#   'great',
#   'bought',
#   '3',
#   'bag',
#   'whole',
#   'bean',
#   'coffe',
#   'onlin',
#   'mistak',
#   'didnt',
#   'want',
#   'return',
#   'bought',
#   'grinder',
#   'fast',
#   'easi',
#   'use',
#   'cleanup',
#   'simpl',
#   'dont',
#   'know',
#   'long',
#   'sort',
#   'applianc',
#   'usual',
#   'last',
#   'regardless',
#   'cheap',
#   'enough',
#   'wouldnt',
#   'mind',
#   'replac',
#   'year',
#   'wonder',
#   'buy',
#   'work',
#   'well',
#   'small',
#   'quantiti',
#   'actual',
#   'grind',
#   'finer',
#   'expens',
#   'grinder',
#   'sever',
#   'set',
#   'said',
#   'grind',
#   'fine',
#   'need',
#   'coaster',
#   'grind',
#   'may',
#   'ideal',
#   'arriv',
#   'proper',
#   'packag',
#   'use',
#   'nearli',
#   'year',
#   'still',
#   'perform',
#   'wonder',
#   'pretti',
#   'good',
#   'coffe',
#   'grinder',
#   'coffe',
#   'tend',
#   'pack',
#   'around',
#   'edg',
#   'insid',
#   'requir',
#   'utensil',
#   'scrape',
#   'coffe',
#   'also',
#   'your',
#   'fine',
#   'grind',
#   'sometim',
#   'hard',
#   'get',
#   'fine',
#   'unless',
#   'fill',
#   'least',
#   '23',
#   'gener',
#   'work',
#   'well',
#   'problem',
#   'motor',
#   'strong',
#   'littl',
#   'grinder',
#   'work',
#   'would',
#   'expect',
#   'issu',
#   'actual',
#   'lid',
#   'get',
#   'foodcoffe',
#   'top',
#   'ned',
#   'turn',
#   'whole',
#   'thing',
#   'upsid',
#   'dow',
#   'pat',
#   'machin',
#   'get',
#   'without',
#   'huge',
#   'mess',
#   'big',
#   'deal',
#   'great',
#   'design',
#   'bought',
#   'grind',
#   'dri',
#   'pepper',
#   'jerki',
#   'curri',
#   'make',
#   'grinder',
#   'work',
#   'great',
#   'youll',
#   'get',
#   'fine',
#   'powder',
#   'care',
#   'though',
#   'dust',
#   'get',
#   'air',
#   'quit',
#   'easili',
#   'like',
#   'youll',
#   'end',
#   'runni',
#   'nose',
#   'sneez',
#   '15',
#   'minut',
#   'oop',
#   'make',
#   'huge',
#   'mess',
#   'coffe',
#   'grind',
#   'everywher',
#   'need',
#   'brush',
#   'get',
#   'grind',
#   'get',
#   'compact',
#   'blade',
#   'come',
#   'unless',
#   'use',
#   'brush',
#   'becom',
#   'mess',
#   'shop',
#   'someth',
#   'els',
#   'buy',
#   'love',
#   'spice',
#   'grinder',
#   'work',
#   'everyth',
#   'liter',
#   'plu',
#   'grind',
#   'coffe',
#   'bean',
#   'occasion',
#   'rel',
#   'smell',
#   'doesnt',
#   'linger',
#   'insid',
#   'afterward',
#   'long',
#   'clean',
#   'well',
#   'wet',
#   'cloth',
#   'complaint',
#   'grinder',
#   'work',
#   'well',
#   'regular',
#   'filter',
#   'coffe',
#   'maker',
#   'found',
#   ...],
#  ['problem',
#   'other',
#   'amazon',
#   'product',
#   'like',
#   'left',
#   'bad',
#   'review',
#   'im',
#   'right',
#   'purchas',
#   'filter',
#   'walmart',
#   'recent',
#   'along',
#   'brand',
#   'new',
#   'brita',
#   'water',
#   'pitcher',
#   'ye',
#   'filter',
#   'pitcher',
#   'new',
#   'compat',
#   'otherand',
#   'filter',
#   'came',
#   'pitcher',
#   'issu',
#   'well',
#   'thought',
#   'crazi',
#   'quit',
#   'bit',
#   'dirti',
#   'water',
#   'leak',
#   'filter',
#   'around',
#   'edg',
#   'filter',
#   'sit',
#   'flush',
#   'pitcher',
#   'hous',
#   'watch',
#   'dirti',
#   'water',
#   'drip',
#   'around',
#   'actual',
#   'filter',
#   'clean',
#   'water',
#   'reservoir',
#   'cring',
#   'scratch',
#   'head',
#   'tripl',
#   'check',
#   'make',
#   'sure',
#   'filter',
#   'properli',
#   'rotat',
#   'insert',
#   'unit',
#   'way',
#   'properli',
#   'push',
#   'darn',
#   'hard',
#   'readi',
#   'unit',
#   'break',
#   'filter',
#   'look',
#   'flush',
#   'water',
#   'pitcher',
#   'housingand',
#   'ala',
#   'water',
#   'still',
#   'leak',
#   'filter',
#   'clearli',
#   'seal',
#   'well',
#   'unit',
#   'find',
#   'almost',
#   'humor',
#   'came',
#   'read',
#   'amazon',
#   'review',
#   'describ',
#   'exact',
#   'issu',
#   'decid',
#   'googl',
#   'problem',
#   'see',
#   'magic',
#   'solut',
#   'see',
#   'brita',
#   'repeatedli',
#   'repli',
#   'sorri',
#   'call',
#   'custom',
#   'servic',
#   'helpor',
#   'need',
#   'insert',
#   'filter',
#   'properli',
#   'line',
#   'firmli',
#   'press',
#   'go',
#   'onto',
#   'brita',
#   'websit',
#   'look',
#   'advanc',
#   'water',
#   'filter',
#   'sale',
#   'check',
#   'custom',
#   'review',
#   'also',
#   'find',
#   'dissapoint',
#   'custom',
#   'complain',
#   'water',
#   'filter',
#   'properli',
#   'seal',
#   'allow',
#   'dirti',
#   'water',
#   'pass',
#   'throughalong',
#   'sad',
#   'respons',
#   'brita',
#   'support',
#   'seemingli',
#   'make',
#   'brita',
#   'look',
#   'like',
#   'theyr',
#   'proactiv',
#   'unfortun',
#   'case',
#   'sometim',
#   'repli',
#   'can',
#   'respons',
#   'dont',
#   'realli',
#   'solv',
#   'problem',
#   'bad',
#   'custom',
#   'servic',
#   'repli',
#   'well',
#   'clearli',
#   'brita',
#   'denial',
#   'wont',
#   'publicli',
#   'accept',
#   'fault',
#   'issu',
#   'think',
#   'worst',
#   'part',
#   'though',
#   'like',
#   'mani',
#   'consum',
#   'get',
#   'new',
#   'brita',
#   'set',
#   'excit',
#   'use',
#   'way',
#   'old',
#   'brita',
#   'filter',
#   'work',
#   'dont',
#   'even',
#   'bother',
#   'look',
#   'care',
#   'see',
#   'whether',
#   'dirti',
#   'water',
#   'get',
#   'filter',
#   'doesnt',
#   'seal',
#   'properlycomplet',
#   'watertight',
#   'fashion',
#   'within',
#   'water',
#   'pitcher',
#   'apparatu',
#   'great',
#   'thing',
#   'brita',
#   'say',
#   'keep',
#   'famili',
#   'safe',
#   'filter',
#   'water',
#   'somewhat',
#   'mislead',
#   'product',
#   'defect',
#   'like',
#   'your',
#   'buy',
#   'filter',
#   'clean',
#   'water',
#   'dont',
#   'even',
#   'notic',
#   'clean',
#   'water',
#   'go',
#   'happili',
#   'ignorantli',
#   'drink',
#   'slightlylessdirti',
#   'water',
#   'still',
#   'contamin',
#   'filter',
#   'doesnt',
#   'seal',
#   'well',
#   'essenti',
#   'function',
#   'function',
#   'water',
#   'filter',
#   'like',
#   'filter',
#   'water',
#   'itif',
#   'product',
#   'cant',
#   'filter',
#   '9999999',
#   'water',
#   'pour',
#   'certainli',
#   'defect',
#   'product',
#   'give',
#   'benefit',
#   'doubt',
#   'brita',
#   'arent',
#   'purpos',
#   'knowingli',
#   'sell',
#   'defect',
#   'filterdesign',
#   'still',
#   'pretti',
#   'appar',
#   'pretti',
#   'high',
#   'number',
#   'manufactur',
#   'defect',
#   'go',
#   'plastic',
#   'isnt',
#   'line',
#   'provid',
#   'perfect',
#   'seal',
#   'water',
#   'pitcher',
#   'advanc',
#   'water',
#   'filter',
#   'fyi',
#   'brita',
#   'custom',
#   'servic',
#   'respond',
#   'messag',
#   'anyth',
#   'less',
#   'someth',
#   'like',
#   'correct',
# ...
#   'work',
#   'great',
#   'love',
#   'simpli',
#   'put',
#   'best',
#   'coffe',
#   'maker',
#   'market',
#   'best',
#   'coffe',
#   'maker',
#   'ever',
#   'own',
#   'expect',
#   'arriv',
#   'time',
#   'excel'],
#  ['work',
#   'great',
#   'far',
#   'ive',
#   'use',
#   'cut',
#   'cucumb',
#   'carrot',
#   'lettuc',
#   'tomato',
#   'potato',
#   'thing',
#   'thick',
#   'thin',
#   'blade',
#   'havent',
#   'problem',
#   'smush',
#   'tomato',
#   'pretti',
#   'easi',
#   'set',
#   'use',
#   'right',
#   'box',
#   'ive',
#   'issu',
#   'uneven',
#   'cut',
#   'im',
#   'pretti',
#   'sure',
#   'fault',
#   'sinc',
#   'hadnt',
#   'use',
#   'one',
#   'coupl',
#   'reason',
#   'took',
#   'one',
#   'star',
#   'there',
#   'easi',
#   'way',
#   'store',
#   'without',
#   'keep',
#   'box',
#   'even',
#   'pain',
#   'get',
#   'everyth',
#   'fit',
#   'back',
#   'nice',
#   'one',
#   'pictur',
#   'show',
#   'nice',
#   'way',
#   'situat',
#   'everyth',
#   'store',
#   'havent',
#   'gotten',
#   'work',
#   'yet',
#   'would',
#   'nice',
#   'bigger',
#   'stand',
#   'someth',
#   'slice',
#   'cut',
#   'mat',
#   'kind',
#   'pain',
#   'wast',
#   'way',
#   'use',
#   'slice',
#   'holder',
#   'got',
#   'safeti',
#   'glove',
#   'would',
#   'recommend',
#   'anyway',
#   'reduc',
#   'wast',
#   'lot',
#   'sinc',
#   'hold',
#   'last',
#   'piec',
#   'slide',
#   'overal',
#   'good',
#   'purchas',
#   'would',
#   'recommend',
#   'one',
#   'use',
#   'lot',
#   'got',
#   'one',
#   'daughter',
#   'christma',
#   'learn',
#   'use',
#   'sharp',
#   'get',
#   'cut',
#   'pretti',
#   'bad',
#   'care',
#   'come',
#   'guard',
#   'realli',
#   'must',
#   'use',
#   'nice',
#   'sharp',
#   'ive',
#   'mandolin',
#   'slicer',
#   '7',
#   'year',
#   'use',
#   'time',
#   'still',
#   'cut',
#   'good',
#   'day',
#   'bought',
#   'thing',
#   'great',
#   'cost',
#   'unbeliv',
#   'work',
#   'great',
#   'thin',
#   'slice',
#   'feel',
#   'safe',
#   'use',
#   'use',
#   'everyth',
#   'easi',
#   'clean',
#   'cut',
#   'almost',
#   'veggi',
#   'less',
#   'minut',
#   'excel',
#   'product',
#   'great',
#   'product',
#   'present',
#   'daughter',
#   'havent',
#   'heard',
#   'anyth',
#   'back',
#   'dont',
#   'know',
#   'like'],
#  ['pillow',
#   'greatest',
#   'aesthet',
#   'qualiti',
#   'great',
#   'agon',
#   'buy',
#   'costli',
#   'pillow',
#   'wasnt',
#   'sure',
#   'would',
#   'work',
#   'im',
#   'glad',
#   'come',
#   'slipcov',
#   'sure',
#   'bit',
#   'flimsi',
#   'ive',
#   'alreadi',
#   'remov',
#   'wash',
#   'fine',
#   'peopl',
#   'turn',
#   'lot',
#   'see',
#   'might',
#   'cumbersom',
#   'start',
#   'ive',
#   'adjust',
#   'easili',
#   'simpli',
#   'pull',
#   'knee',
#   'rotat',
#   'put',
#   'easi',
#   'middl',
#   'night',
#   'turn',
#   'favorit',
#   'matern',
#   'purchas',
#   'sure',
#   'alreadi',
#   'use',
#   'babysat',
#   'niec',
#   '7mo',
#   'bumper',
#   'bed',
#   'prevent',
#   'roll',
#   'im',
#   'excit',
#   'keep',
#   'use',
#   'matern',
#   'well',
#   'final',
#   'relief',
#   'bought',
#   'pillow',
#   'lay',
#   'hospit',
#   'bed',
#   '11',
#   'day',
#   'compress',
#   'fractur',
#   'spine',
#   'due',
#   'fall',
#   'know',
#   'seem',
#   'mostli',
#   'pregnant',
#   'women',
#   'use',
#   'pillow',
#   'certainli',
#   'understand',
#   'also',
#   'wonder',
#   'altern',
#   'peopl',
#   'pain',
#   'also',
#   'fibromyalgia',
#   'bursiti',
#   'shoulder',
#   'osteoarthr',
#   'hip',
#   'back',
#   'knee',
#   'believ',
#   'know',
#   'pain',
#   'due',
#   'awesom',
#   'pillow',
#   'final',
#   'relief',
#   'may',
#   'never',
#   'want',
#   'get',
#   'bed',
#   'pregnant',
#   'great',
#   'end',
#   'second',
#   'trimest',
#   'didnt',
#   'even',
#   'gain',
#   'much',
#   'weight',
#   'sheer',
#   'size',
#   'belli',
#   'uncomfort',
#   'matter',
#   'laid',
#   'left',
#   'side',
#   'bed',
#   'snoogl',
#   'boyfriend',
#   'quickli',
#   'grew',
#   'jealou',
#   'pillow',
#   'start',
#   'realli',
#   'reli',
#   'heavili',
#   'pun',
#   'intend',
#   'cuddl',
#   'night',
#   'instead',
#   'held',
#   'weight',
#   'sweat',
#   '7',
#   'month',
#   'pregnant',
#   'florida',
#   'summer',
#   'even',
#   'took',
#   'disney',
#   'world',
#   'mom',
#   'sciatica',
#   'absolut',
#   'love',
#   'pillow',
#   'grant',
#   'love',
#   'pillow',
#   'one',
#   'unlik',
#   'regular',
#   'bodi',
#   'better',
#   'nice',
#   'firm',
#   'actual',
#   'give',
#   'support',
#   'come',
#   'sheet',
#   'give',
#   'differ',
#   'idea',
#   'use',
#   'pillow',
#   'versatil',
#   'mani',
#   'use',
#   'even',
#   'seen',
#   'walk',
#   'around',
#   'hous',
#   'wrap',
#   'around',
#   'bodi',
#   'like',
#   'snake',
#   'got',
#   'dog',
#   'got',
#   'jealou',
#   'think',
#   'say',
#   'someth',
#   'wife',
#   'realli',
#   'hard',
#   'time',
#   'get',
#   'comfort',
#   'night',
#   'pregnanc',
#   'ton',
#   'research',
#   'settl',
#   'didnt',
#   'want',
#   'someth',
#   'super',
#   'massiv',
#   'point',
#   'would',
#   'essenti',
#   'sleep',
#   'floor',
#   'pillow',
#   'perfect',
#   'companion',
#   'bed',
#   'big',
#   'yet',
#   'hit',
#   'comfort',
#   'point',
#   'share',
#   'bed',
#   'someon',
#   'bed',
#   'smaller',
#   'queen',
#   'probabl',
#   'isnt',
#   'right',
#   'pillow',
#   'purchas',
#   'fianc',
#   'great',
#   'first',
#   'month',
#   'product',
#   'even',
#   'last',
#   '7',
#   'month',
#   'time',
#   '8',
#   'month',
#   'pregnanc',
#   'pillow',
#   'longer',
#   'fluffi',
#   'retain',
#   'shape',
#   'addit',
#   'pillow',
#   'cover',
#   'comfort',
#   'tailor',
#   'pillow',
#   'cover',
#   'fabric',
#   'cover',
#   'offer',
#   'leachco',
#   'rough',
#   'made',
#   'skin',
#   'itch',
#   'materi',
#   'nice',
#   'soft',
#   'sister',
#   'purchas',
#   'item',
#   'within',
#   'first',
#   'trimest',
#   'use',
#   'much',
#   'mayb',
#   'middl',
#   'second',
#   'trimest',
#   'began',
#   'use',
#   'snoogl',
#   'use',
#   'night',
#   'goe',
#   'bed',
#   'side',
#   'snoogl',
#   'sister',
#   'brotherinlaw',
#   'think',
#   'pillow',
#   'cover',
#   'take',
#   'difficult',
#   'put',
#   'back',
#   'open',
#   'pillow',
#   'cover',
#   'one',
#   'end',
#   'mean',
#   'put',
#   'entir',
#   'pillow',
#   'cover',
#   'back',
#   'one',
#   'end',
#   'pull',
#   'pillow',
#   'cover',
#   'way',
#   'end',
#   'pillow',
#   'thought',
#   'would',
#   'better',
#   'mayb',
#   'zipper',
#   'involv',
#   'would',
#   'easier',
#   'put',
#   'cover',
#   'back',
#   'pillow',
#   'overal',
#   'still',
#   'nice',
#   'pillow',
#   'wife',
#   'impress',
#   'doesnt',
#   'realli',
#   'support',
#   'back',
#   'best',
#   'might',
#   'keep',
#   'back',
#   'warm',
#   'nice',
#   'pillow',
#   'leg',
#   'dont',
#   'need',
#   'total',
#   'bodi',
#   'pillow',
#   'didnt',
#   'like',
#   'couldnt',
#   'use',
#   'regular',
#   'pillow',
#   'head',
#   'use',
#   'mostli',
#   'sit',
#   'side',
#   'bed',
#   'first',
#   'pregnanc',
#   'pillow',
#   'purchas',
#   'return',
#   'jersey',
#   'version',
#   'version',
#   'weird',
#   'cover',
#   'super',
#   'scratchi',
#   'uncomfort',
#   'neck',
#   'part',
#   'also',
#   'diggi',
#   'dont',
#   'problem',
#   'jersey',
#   'version',
#   'though',
#   'look',
#   'pay',
#   'coupl',
#   'extra',
#   'dollar',
#   'get',
#   'jersey',
#   'chic',
#   'version',
#   'pillow',
#   'didnt',
#   'want',
#   'cave',
#   'get',
#   'pregnanc',
#   'pillow',
#   'price',
#   'glad',
#   'pillow',
#   'complet',
#   'take',
#   'away',
#   'back',
#   'pain',
#   'sleep',
#   'make',
#   'sleep',
#   'whole',
#   'lot',
#   'comfort',
#   'use',
#   'everi',
#   'night',
#   'even',
#   'day',
#   'lay',
#   'floor',
#   'highli',
#   'recommend',
#   'love',
#   'product',
#   'bought',
#   'last',
#   'year',
#   'buy',
#   'new',
#   'one',
#   'excit',
#   'truli',
#   'amaz',
#   'product',
#   'howev',
#   'im',
#   'sure',
#   'someth',
#   'chang',
#   'stuf',
#   'pillow',
#   'give',
#   'terribl',
#   'headach',
#   'cant',
#   'use',
#   'huge',
#   'wast',
#   'pillow',
#   'complet',
#   'worth',
#   'start',
#   'sleep',
#   'snoogl',
#   '56',
#   'month',
#   'pregnant',
#   'found',
#   'couldnt',
#   'sleep',
#   'without',
#   'even',
#   'husband',
#   'comment',
#   'comfort',
#   'definit',
#   'worth',
#   'hard',
#   'big',
#   'would',
#   'love',
#   'allow',
#   'use',
#   'pillow',
#   'big',
#   'use',
#   'pillow',
#   'hard',
#   'high',
#   'make',
#   'neck',
#   'stiff',
#   'morn',
#   'realli',
#   'hate',
#   'thought',
#   'would',
#   'love',
#   'take',
#   'much',
#   'space',
#   'like',
#   'third',
#   'person',
#   'bed',
#   'us',
#   'also',
#   'think',
#   'may',
#   'littl',
#   'tall',
#   '6',
#   'feet',
#   'tall',
#   'hard',
#   'get',
#   'comfort',
#   'around',
#   '18',
#   'week',
#   'start',
#   'becom',
#   'uncomfort',
#   'sleep',
#   'help',
#   'tremend',
#   'suggest',
#   'buy',
#   'jersey',
#   'cover',
#   'origin',
#   'cover',
#   'bit',
#   'rough',
#   'feel',
#   'skin',
#   'love',
#   'pillow',
#   'use',
#   'two',
#   'pregnanc',
#   'one',
#   'major',
#   'surgeri',
#   'life',
#   'saver',
#   'especi',
#   'last',
#   'trimest',
#   'need',
#   'jersey',
#   'cover',
#   'make',
#   'realli',
#   'comfort',
#   'though',
#   'comfort',
#   'durabl',
#   'could',
#   'sleep',
#   'hug',
#   'pillow',
#   'well',
#   'use',
#   'back',
#   'support',
#   'want',
#   'roll',
#   'say',
#   'wish',
#   'bought',
#   'item',
#   'earlier',
#   'realli',
#   'help',
#   'sleep',
#   'issu',
#   'great',
#   'product',
#   'great',
#   'price',
#   'thank',
#   'absolut',
#   'love',
#   'im',
#   'first',
#   'trimest',
#   'realli',
#   'help',
#   'support',
#   'back',
#   'without',
#   'cant',
#   'sleep',
#   'side',
#   'pillow',
#   'awesom',
#   'super',
#   'comfi',
#   'work',
#   'well',
#   'love',
#   'much',
#   'husband',
#   'like',
#   'steal',
#   'bought',
#   'pregnant',
#   'daughter',
#   'love',
#   'much',
#   'bought',
#   'anoth',
#   'comfort',
#   'supportivesleep',
#   'like',
#   'rock',
#   'great',
#   'dont',
#   'move',
#   'around',
#   'much',
#   'bed',
#   'need',
#   'someth',
#   'could',
#   'roll',
#   'way',
#   'larg',
#   'bought',
#   'help',
#   'back',
#   'pain',
#   'pregnant',
#   'end',
#   'love',
#   'nurs',
#   'bed',
#   'absolut',
#   'worth',
#   'recommend',
#   'pillow',
#   'everyon',
#   'pregnant',
#   'pregnant',
#   'im',
#   'final',
#   'get',
#   'good',
#   'night',
#   'sleep',
#   'great',
#   'buy',
#   'wife',
#   'love',
#   'pillow',
#   'unfortun',
#   'longer',
#   'snuggl',
#   'must',
#   'pregnant',
#   'woman',
#   'good',
#   'pillow',
#   'shame',
#   'made',
#   'shape',
#   'cant',
#   'make',
#   'straight',
#   'sinc',
#   'get',
#   'littl',
#   'uncomfi',
#   'pregnant',
#   'back',
#   'issu',
#   'pillow',
#   'ideal',
#   'pillow',
#   'need',
#   'pregnanc',
#   'almost',
#   'like',
#   'boyfriend',
#   'say',
#   'wife',
#   'think',
#   'joke',
#   'anyway',
#   'she',
#   'happi',
#   'wife',
#   'didnt',
#   'like',
#   'product',
#   'first',
#   'glanc',
#   'soon',
#   'slept',
#   'love',
#   'love',
#   'snoogl',
#   'quickli',
#   'turn',
#   'pregnanc',
#   'essenti',
#   'cant',
#   'sleep',
#   'without',
#   'cant',
#   'leav',
#   'without',
#   'pillow',
#   'either',
#   'side',
#   'super',
#   'comfi',
#   'sleep',
#   'worth',
#   'everi',
#   'penni',
#   'thing',
#   'super',
#   'comfi',
#   'got',
#   'pregnant',
#   'wife',
#   'end',
#   'use',
#   'sciatica',
#   'well',
#   'want',
#   'wife',
#   'stop',
#   'cuddl',
#   'night',
#   'time',
#   'sleep',
#   'buy',
#   'bought',
#   'sister',
#   'pregnant',
#   'use',
#   'first',
#   'night',
#   'said',
#   'love',
#   'much',
#   'troubl',
#   'sleep',
#   'complet',
#   'elimin',
#   'discomfort',
#   'best',
#   'friend',
#   'pregnant',
#   'help',
#   'sleep',
#   'comfort',
#   'best',
#   'pregnanc',
#   'pillow',
#   'fat',
#   'easi',
#   'cuddl',
#   'bought',
#   'daughter',
#   'love',
#   'would',
#   'nice',
#   'extra',
#   'cover',
#   'lot',
#   'chose',
#   'end',
#   'im',
#   'glad',
#   'chose',
#   'one',
#   'love',
#   'bought',
#   'daughter',
#   'love',
#   'fast',
#   'ship',
#   'wife',
#   'love',
#   'pillow',
#   '2nd',
#   '3rd',
#   'trimest',
#   'use',
#   '5',
#   'month',
#   'cant',
#   'imagin',
#   'sleep',
#   'without',
#   'ladi',
#   'love',
#   'pillow',
#   'happi',
#   'wife',
#   'happi',
#   'life',
#   'lol',
#   'best',
#   'gift',
#   'expect',
#   'mom',
#   'easi',
#   'wash',
#   'without',
#   'pillow',
#   'sleep',
#   'uncomfort',
#   'big',
#   'somebodi',
#   'like',
#   'comfort',
#   'love',
#   'return',
#   'thank',
#   'great',
#   'difficult',
#   'put',
#   'imposs',
#   'need',
#   'larger',
#   'open',
#   'possibl',
#   'zipper',
#   'velcreo'],
#  ['fun',
#   'product',
#   'confus',
#   'joseph',
#   'one',
#   'wisemen',
#   'short',
#   'period',
#   'time',
#   'look',
#   'one',
#   'hold',
#   'anyth',
#   'nois',
#   'loud',
#   'doesnt',
#   'last',
#   'long',
#   'help',
#   'piec',
#   'fit',
#   'top',
#   'make',
#   'even',
#   'fun',
#   'children',
#   'simpl',
#   'assembl',
#   'also',
#   'got',
#   'niec',
#   'love',
#   'play',
#   'quit',
#   'time',
#   'get',
#   'distract',
#   'came',
#   'back',
#   'toy',
#   'lot',
#   'day',
#   'great',
#   'way',
#   'children',
#   'nativ',
#   'play',
#   'parent',
#   'untouch',
#   'kind',
#   'perfect',
#   '2',
#   'year',
#   'old',
#   '4',
#   'year',
#   'old',
#   'need',
#   'someth',
#   'would',
#   'allow',
#   'play',
#   'rememb',
#   'grow',
#   'alway',
#   'want',
#   'play',
#   'set',
#   'parent',
#   'never',
#   'allow',
#   'touch',
#   'tortur',
#   'lol',
#   'one',
#   'cute',
#   'fun',
#   'kid',
#   'book',
#   'buy',
#   'addit',
#   'also',
#   'great',
#   'kid',
#   'blast',
#   'reenact',
#   'book',
#   'charact',
#   'brand',
#   'new',
#   'price',
#   'better',
#   'site',
#   'look',
#   'think',
#   'daughter',
#   'thrill',
#   'grandson',
#   'alway',
#   'nativ',
#   'scene',
#   'handl',
#   'learn',
#   'appreci',
#   'repres',
#   'grandchildren',
#   'love',
#   'pick',
#   'piec',
#   'nativ',
#   'scene',
#   'got',
#   'one',
#   'love',
#   'pick',
#   'piec',
#   'move',
#   'around',
#   'without',
#   'worri',
#   'drop',
#   'break',
#   'gave',
#   'gift',
#   'sister',
#   'littl',
#   'girl',
#   'great',
#   'product',
#   'littl',
#   'kid',
#   'nativ',
#   'set',
#   'play',
#   'one',
#   'dont',
#   'get',
#   'broken',
#   '2',
#   'year',
#   'old',
#   'love',
#   'lp',
#   'nativ',
#   'scene',
#   'learn',
#   'christma',
#   'stori',
#   'well',
#   'play',
#   'throughout',
#   'christma',
#   'season',
#   'love',
#   'great',
#   'qualiti',
#   'kid',
#   'love',
#   'play',
#   'much',
#   'sad',
#   'see',
#   'charact',
#   'get',
#   'pack',
#   'christma',
#   'box',
#   'next',
#   'year',
#   'good',
#   'littl',
#   'set',
#   'come',
#   'lot',
#   'piec',
#   'inevit',
#   'end',
#   'live',
#   'room',
#   'floor',
#   'price',
#   'valu',
#   'good',
#   'super',
#   'cute',
#   'put',
#   'xma',
#   'decor',
#   'holiday',
#   'grandson',
#   'love',
#   'much',
#   'im',
#   'keep',
#   'love',
#   'share',
#   'christma',
#   'stori',
#   'toddler',
#   'grandchildren',
#   'thank',
#   'love',
#   'nativ',
#   'set',
#   'deliv',
#   'promis',
#   'cute',
#   'granddaught',
#   'love',
#   'great',
#   'qualiti',
#   'son',
#   'love',
#   'grand',
#   'daughter',
#   'love',
#   'wonder',
#   'gift',
#   'everi',
#   'child'],
#  ['noth',
#   'wrong',
#   'replac',
#   '3',
#   'year',
#   'use',
#   'blade',
#   'came',
#   'shave',
#   'experi',
#   'chang',
#   'whatsoev',
#   'get',
#   'new',
#   'blade',
#   'differ',
#   'feel',
#   'like',
#   'shaver',
#   'work',
#   'littl',
#   'harder',
#   'there',
#   'littl',
#   'less',
#   'nois',
#   'shave',
#   'cut',
#   'improv',
#   'head',
#   'ok',
#   'ship',
#   'time',
#   'ok',
#   'price',
#   'howev',
#   'went',
#   '5',
#   'past',
#   'year',
#   'that',
#   '25',
#   'one',
#   'year',
#   'much',
#   'sinc',
#   'bought',
#   'razor',
#   'littl',
#   'choic',
#   'bug',
#   'though',
#   'first',
#   'time',
#   'buy',
#   'bazinga',
#   'tread',
#   'amazon',
#   'talk',
#   'quick',
#   'respons',
#   'ship',
#   'im',
#   'prioriti',
#   'custom',
#   'price',
#   'reason',
#   '5',
#   'star',
#   'happi',
#   'custom',
#   'super',
#   'product',
#   'razor',
#   'five',
#   'year',
#   'old',
#   'still',
#   'work',
#   'well',
#   'phillip',
#   'catalog',
#   'confus',
#   'hard',
#   'pick',
#   'correct',
#   'replac',
#   'head',
#   'second',
#   'time',
#   'ive',
#   'purchas',
#   'replac',
#   'head',
#   'buy',
#   'one',
#   'everi',
#   'year',
#   'shaver',
#   'like',
#   'new',
#   'noth',
#   'wrong',
#   'product',
#   'order',
#   'wrong',
#   'size',
#   'easi',
#   'return',
#   'get',
#   'correct',
#   'size',
#   'item',
#   'bent',
#   'didnt',
#   'work',
#   'go',
#   'bed',
#   'bath',
#   'get',
#   'good',
#   'one',
#   'need',
#   'reorder',
#   'one',
#   '3',
#   'blade',
#   'dull',
#   'make',
#   'wonder',
#   'factori',
#   'replac',
#   'head',
#   'expect',
#   'ship',
#   'issu',
#   'resent',
#   'problem',
#   'improv',
#   'shave',
#   'experi',
#   'new',
#   'blade',
#   'fit',
#   'like',
#   'origin',
#   'blade',
#   'use',
#   'less',
#   'sinc',
#   'grew',
#   'back',
#   'beard',
#   'still',
#   'great',
#   'trim',
#   'realli',
#   'didnt',
#   'notic',
#   'differ',
#   'exist',
#   'new',
#   'one',
#   'easi',
#   'shop',
#   'good',
#   'price',
#   'next',
#   'replacemenet',
#   'receiv',
#   'foil',
#   'replac',
#   'expect',
#   'complet',
#   'head',
#   'best',
#   'way',
#   'godont',
#   'throw',
#   'money',
#   'away',
#   'new',
#   'electr',
#   'razor',
#   'use',
#   'year',
#   'give',
#   'great',
#   'shave',
#   'good',
#   'replac',
#   'norelco',
#   'keep',
#   'new',
#   'cut',
#   'close',
#   'like',
#   'origin',
#   'blade',
#   'great',
#   'product',
#   'would',
#   'buy',
#   'husband',
#   'love',
#   'great',
#   'valu',
#   'make',
#   'old',
#   'razor',
#   'like',
#   'new',
#   'fit',
#   'razor',
#   'list',
#   'pleas',
#   'work',
#   'great',
#   'expect',
#   'easi',
#   'repalc',
#   'advertis',
#   'perfect',
#   'great',
#   'work',
#   'none',
#   'ok']]

# %%
dictionary = corpora.Dictionary(doc_stemmed)
corpus = [dictionary.doc2bow(text) for text in doc_stemmed]
ldamodel = models.ldamodel.LdaModel(corpus, num_topics=10, id2word = dictionary, passes = 20,chunksize=10000)

# %%
ldamodel.print_topics(num_topics=10, num_words=3)
# Out:
# [(0, u'0.021*"pillow" + 0.021*"love" + 0.021*"great"'),
#  (1, u'0.001*"use" + 0.001*"great" + 0.001*"work"'),
#  (2, u'0.031*"grind" + 0.031*"coffe" + 0.026*"use"'),
#  (3, u'0.027*"great" + 0.022*"use" + 0.021*"band"'),
#  (4, u'0.001*"use" + 0.001*"work" + 0.001*"bottl"'),
#  (5, u'0.022*"use" + 0.022*"work" + 0.019*"thermomet"'),
#  (6, u'0.019*"use" + 0.017*"fire" + 0.011*"one"'),
#  (7, u'0.031*"filter" + 0.026*"water" + 0.022*"popcorn"'),
#  (8, u'0.001*"use" + 0.001*"great" + 0.001*"love"'),
#  (9, u'0.032*"window" + 0.017*"use" + 0.014*"room"')]

# %%
raw_topics = [s for n,s in ldamodel.print_topics(num_topics=10, num_words=3)]
strip = '0123456789*."'
topics = [''.join([i for i in s.encode().replace(" +",",") if not i in strip]).replace(" +", ",") for s in raw_topics]

# %%
topics
# Out:
# ['pillow, love, great',
#  'use, great, work',
#  'grind, coffe, use',
#  'great, use, band',
#  'use, work, bottl',
#  'use, work, thermomet',
#  'use, fire, one',
#  'filter, water, popcorn',
#  'use, great, love',
#  'window, use, room']

# %%
prob_1 = []
prob_2 = []
for i in range(len(corpus)):
    df = pd.DataFrame(zip(topics,[p for t, p in ldamodel.get_document_topics(corpus[i],minimum_probability=1e-5)]),
                      columns = ["topics","prob"])
    df.sort_values(by = "prob", ascending=0,inplace=True)
    df = df.head(2)
    df["top_two"] = df.prob.map(str) + "*[" + df.topics + "]"
    prob_1.append(df.top_two.values[0])
    prob_2.append(df.top_two.values[1])
result = pd.DataFrame(zip(range(1,20),prob_1,prob_2),
                      columns=(["Product ID","Probability*Topic 1", "Probability*Topic 2"]))
result
# Out:
#     Product ID                      Probability*Topic 1  \
# 0            1        0.999091744556*[great, use, band]
# 1            2       0.998734050553*[window, use, room]
# 2            3          0.996841809942*[use, fire, one]
# 3            4        0.997413533143*[great, use, band]
# 4            5       0.996979495727*[grind, coffe, use]
# 5            6      0.99777203271*[pillow, love, great]
# 6            7        0.636308426037*[great, use, band]
# 7            8       0.999433906749*[grind, coffe, use]
# 8            9  0.999164259682*[filter, water, popcorn]
# 9           10  0.999048524072*[filter, water, popcorn]
# 10          11    0.993128996417*[use, work, thermomet]
# 11          12  0.989533526852*[filter, water, popcorn]
# 12          13          0.995312040125*[use, fire, one]
# 13          14     0.998621599298*[pillow, love, great]
# 14          15     0.752645026038*[pillow, love, great]
# 15          16          0.994705181937*[use, fire, one]
# 16          17     0.998928478139*[pillow, love, great]
# 17          18        0.995927125152*[great, use, band]
# 18          19         0.99605222392*[great, use, band]
#
#                            Probability*Topic 2
# 0       0.00010092643501*[pillow, love, great]
# 1         0.000140674024086*[great, use, band]
# 2      0.000350936779843*[pillow, love, great]
# 3        0.000287416796555*[grind, coffe, use]
# 4         0.000335672279839*[great, use, band]
# 5        0.000247584530518*[grind, coffe, use]
# 6           0.223340122026*[grind, coffe, use]
# 7      6.29049117551e-05*[pillow, love, great]
# 8         9.28692022928e-05*[great, use, band]
# 9          0.00010573118059*[great, use, band]
# 10        0.000763529485866*[great, use, band]
# 11        0.001163229651*[pillow, love, great]
# 12  0.000520942707765*[filter, water, popcorn]
# 13        0.000153172088202*[great, use, band]
# 14          0.235759773891*[grind, coffe, use]
# 15        0.000588414766836*[great, use, band]
# 16        0.000119066432359*[great, use, band]
# 17     0.000452616982967*[pillow, love, great]
# 18       0.000438680796101*[grind, coffe, use]
